# %% [markdown]
# # FE012 - Distance times mass of neighbors

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import os
import gc

# %% [markdown]
# # One Type of Molecule and Train/Test done one at a time

# %% [markdown]
# ## Test on first type

# %%
f_files = [x for x in os.listdir('../data/') if 'FE010' in x]
f_files
# Out:
# ['FE010-test-1JHN.parquet',
#  'FE010-train-2JHC.parquet',
#  'FE010-test-3JHC.parquet',
#  'FE010-train-3JHN.parquet',
#  'FE010-test-2JHC.parquet',
#  'FE010-train-2JHH.parquet',
#  'FE010-test-2JHH.parquet',
#  'FE010-train-1JHC.parquet',
#  'FE010-train-2JHN.parquet',
#  'FE010-test-3JHN.parquet',
#  'FE010-train-1JHN.parquet',
#  'FE010-train-3JHC.parquet',
#  'FE010-test-1JHC.parquet',
#  'FE010-train-3JHH.parquet',
#  'FE010-test-2JHN.parquet',
#  'FE010-test-3JHH.parquet']

# %%
for f in f_files:
    df = pd.read_parquet('../data/' + f)
    df['closest_to_0_dist_x_atomic_mass'] = df['distance_closest_to_0'] * df['closest_to_0_atomic_mass']
    df['2nd_closest_to_0_dist_x_atomic_mass'] = df['distance_2nd_closest_to_0'] * df['2nd_closest_to_0_atomic_mass']
    df['3rd_closest_to_0_dist_x_atomic_mass'] = df['distance_3rd_closest_to_0'] * df['3rd_closest_to_0_atomic_mass']
    df['4th_closest_to_0_dist_x_atomic_mass'] = df['distance_4th_closest_to_0'] * df['4th_closest_to_0_atomic_mass']
    df['5th_closest_to_0_dist_x_atomic_mass'] = df['distance_5th_closest_to_0'] * df['5th_closest_to_0_atomic_mass']
    df['6th_closest_to_0_dist_x_atomic_mass'] = df['distance_6th_closest_to_0'] * df['6th_closest_to_0_atomic_mass']
    df['7th_closest_to_0_dist_x_atomic_mass'] = df['distance_7th_closest_to_0'] * df['7th_closest_to_0_atomic_mass']
    df['8th_closest_to_0_dist_x_atomic_mass'] = df['distance_8th_closest_to_0'] * df['8th_closest_to_0_atomic_mass']
    df['9th_closest_to_0_dist_x_atomic_mass'] = df['distance_9th_closest_to_0'] * df['9th_closest_to_0_atomic_mass']
    df['10th_closest_to_0_dist_x_atomic_mass'] = df['distance_10th_closest_to_0'] * df['10th_closest_to_0_atomic_mass']
    df['12th_closest_to_0_dist_x_atomic_mass'] = df['distance_12th_closest_to_0'] * df['12th_closest_to_0_atomic_mass']
    df['13th_closest_to_0_dist_x_atomic_mass'] = df['distance_13th_closest_to_0'] * df['13th_closest_to_0_atomic_mass']
    df['14th_closest_to_0_dist_x_atomic_mass'] = df['distance_14th_closest_to_0'] * df['14th_closest_to_0_atomic_mass']
    df['15th_closest_to_0_dist_x_atomic_mass'] = df['distance_15th_closest_to_0'] * df['15th_closest_to_0_atomic_mass']
    df['16th_closest_to_0_dist_x_atomic_mass'] = df['distance_16th_closest_to_0'] * df['16th_closest_to_0_atomic_mass']
    df['17th_closest_to_0_dist_x_atomic_mass'] = df['distance_17th_closest_to_0'] * df['17th_closest_to_0_atomic_mass']
    df['18th_closest_to_0_dist_x_atomic_mass'] = df['distance_18th_closest_to_0'] * df['18th_closest_to_0_atomic_mass']
    df['19th_closest_to_0_dist_x_atomic_mass'] = df['distance_19th_closest_to_0'] * df['19th_closest_to_0_atomic_mass']
    df['20th_closest_to_0_dist_x_atomic_mass'] = df['distance_20th_closest_to_0'] * df['20th_closest_to_0_atomic_mass']
    df['21st_closest_to_0_dist_x_atomic_mass'] = df['distance_21st_closest_to_0'] * df['21st_closest_to_0_atomic_mass']
    df['22nd_closest_to_0_dist_x_atomic_mass'] = df['distance_22nd_closest_to_0'] * df['22nd_closest_to_0_atomic_mass']
    df['23rd_closest_to_0_dist_x_atomic_mass'] = df['distance_23rd_closest_to_0'] * df['23rd_closest_to_0_atomic_mass']
    df['24th_closest_to_0_dist_x_atomic_mass'] = df['distance_24th_closest_to_0'] * df['24th_closest_to_0_atomic_mass']
    df['25th_closest_to_0_dist_x_atomic_mass'] = df['distance_25th_closest_to_0'] * df['25th_closest_to_0_atomic_mass']
    df['26th_closest_to_0_dist_x_atomic_mass'] = df['distance_26th_closest_to_0'] * df['26th_closest_to_0_atomic_mass']
    df['27th_closest_to_0_dist_x_atomic_mass'] = df['distance_27th_closest_to_0'] * df['27th_closest_to_0_atomic_mass']
    df['28th_closest_to_0_dist_x_atomic_mass'] = df['distance_28th_closest_to_0'] * df['28th_closest_to_0_atomic_mass']
    df['closest_to_1_dist_x_atomic_mass'] = df['distance_closest_to_1'] * df['closest_to_1_atomic_mass']
    df['2nd_closest_to_1_dist_x_atomic_mass'] = df['distance_2nd_closest_to_1'] * df['2nd_closest_to_1_atomic_mass']
    df['3rd_closest_to_1_dist_x_atomic_mass'] = df['distance_3rd_closest_to_1'] * df['3rd_closest_to_1_atomic_mass']
    df['4th_closest_to_1_dist_x_atomic_mass'] = df['distance_4th_closest_to_1'] * df['4th_closest_to_1_atomic_mass']
    df['5th_closest_to_1_dist_x_atomic_mass'] = df['distance_5th_closest_to_1'] * df['5th_closest_to_1_atomic_mass']
    df['6th_closest_to_1_dist_x_atomic_mass'] = df['distance_6th_closest_to_1'] * df['6th_closest_to_1_atomic_mass']
    df['7th_closest_to_1_dist_x_atomic_mass'] = df['distance_7th_closest_to_1'] * df['7th_closest_to_1_atomic_mass']
    df['8th_closest_to_1_dist_x_atomic_mass'] = df['distance_8th_closest_to_1'] * df['8th_closest_to_1_atomic_mass']
    df['9th_closest_to_1_dist_x_atomic_mass'] = df['distance_9th_closest_to_1'] * df['9th_closest_to_1_atomic_mass']
    df['10th_closest_to_1_dist_x_atomic_mass'] = df['distance_10th_closest_to_1'] * df['10th_closest_to_1_atomic_mass']
    df['12th_closest_to_1_dist_x_atomic_mass'] = df['distance_12th_closest_to_1'] * df['12th_closest_to_1_atomic_mass']
    df['13th_closest_to_1_dist_x_atomic_mass'] = df['distance_13th_closest_to_1'] * df['13th_closest_to_1_atomic_mass']
    df['14th_closest_to_1_dist_x_atomic_mass'] = df['distance_14th_closest_to_1'] * df['14th_closest_to_1_atomic_mass']
    df['15th_closest_to_1_dist_x_atomic_mass'] = df['distance_15th_closest_to_1'] * df['15th_closest_to_1_atomic_mass']
    df['16th_closest_to_1_dist_x_atomic_mass'] = df['distance_16th_closest_to_1'] * df['16th_closest_to_1_atomic_mass']
    df['17th_closest_to_1_dist_x_atomic_mass'] = df['distance_17th_closest_to_1'] * df['17th_closest_to_1_atomic_mass']
    df['18th_closest_to_1_dist_x_atomic_mass'] = df['distance_18th_closest_to_1'] * df['18th_closest_to_1_atomic_mass']
    df['19th_closest_to_1_dist_x_atomic_mass'] = df['distance_19th_closest_to_1'] * df['19th_closest_to_1_atomic_mass']
    df['20th_closest_to_1_dist_x_atomic_mass'] = df['distance_20th_closest_to_1'] * df['20th_closest_to_1_atomic_mass']
    df['21st_closest_to_1_dist_x_atomic_mass'] = df['distance_21st_closest_to_1'] * df['21st_closest_to_1_atomic_mass']
    df['22nd_closest_to_1_dist_x_atomic_mass'] = df['distance_22nd_closest_to_1'] * df['22nd_closest_to_1_atomic_mass']
    df['23rd_closest_to_1_dist_x_atomic_mass'] = df['distance_23rd_closest_to_1'] * df['23rd_closest_to_1_atomic_mass']
    df['24th_closest_to_1_dist_x_atomic_mass'] = df['distance_24th_closest_to_1'] * df['24th_closest_to_1_atomic_mass']
    df['25th_closest_to_1_dist_x_atomic_mass'] = df['distance_25th_closest_to_1'] * df['25th_closest_to_1_atomic_mass']
    df['26th_closest_to_1_dist_x_atomic_mass'] = df['distance_26th_closest_to_1'] * df['26th_closest_to_1_atomic_mass']
    df['27th_closest_to_1_dist_x_atomic_mass'] = df['distance_27th_closest_to_1'] * df['27th_closest_to_1_atomic_mass']
    df['28th_closest_to_1_dist_x_atomic_mass'] = df['distance_28th_closest_to_1'] * df['28th_closest_to_1_atomic_mass']
    df.to_parquet('../data/' + f.replace('FE010','FE012'))

# %%
[x for x in df.columns]
# Out:
# ['id',
#  'molecule_name',
#  'atom_index_0',
#  'atom_index_1',
#  'type',
#  'scalar_coupling_constant',
#  'atom0_atomic_mass',
#  'atom0_atomic_number',
#  'exact_mass_x',
#  'atom0_valence',
#  'atom0_spin_multiplicity',
#  'atom1_atomic_mass',
#  'atom1_atomic_number',
#  'exact_mass_y',
#  'atom1_valence',
#  'atom1_spin_multiplicity',
#  'left_middle_average_angle',
#  'right_middle_average_angle',
#  'distance',
#  'is_bond',
#  'closest_to_0',
#  '2nd_closest_to_0',
#  '3rd_closest_to_0',
#  '4th_closest_to_0',
#  '5th_closest_to_0',
#  '6th_closest_to_0',
#  '7th_closest_to_0',
#  '8th_closest_to_0',
#  '9th_closest_to_0',
#  '10th_closest_to_0',
#  'closest_to_1',
#  '2nd_closest_to_1',
#  '3rd_closest_to_1',
#  '4th_closest_to_1',
#  '5th_closest_to_1',
#  '6th_closest_to_1',
#  '7th_closest_to_1',
#  '8th_closest_to_1',
#  '9th_closest_to_1',
#  '10th_closest_to_1',
#  'is_closest_pair',
#  'distance_closest_to_0',
#  'is_bond_closest_to_0',
# ...

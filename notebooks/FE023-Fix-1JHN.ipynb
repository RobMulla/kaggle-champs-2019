# %% [markdown]
# # 1JHN - Add more features - something was missed in FE021
# - Create FE023

# %%
M053 = [
    "10th_closest_to_0_atomic_mass_x_cube_inv_dist",
    "10th_closest_to_0_valence_x_cube_inv_dist",
    "10th_closest_to_1_atomic_mass_x_cube_inv_dist",
    "10th_closest_to_1_valence_x_cube_inv_dist",
    "12th_closest_to_0_atomic_mass_x_cube_inv_dist",
    "12th_closest_to_1_atomic_mass_x_cube_inv_dist",
    "13th_closest_to_1_atomic_mass_x_cube_inv_dist",
    "14th_closest_to_1_atomic_mass_x_cube_inv_dist",
    "21st_closest_to_0_atomic_mass_x_cube_inv_dist",
    "2nd_closest_to_0_atomic_mass",
    "2nd_closest_to_0_atomic_mass_x_cube_inv_dist",
    "2nd_closest_to_0_dist_x_atomic_mass",
    "2nd_closest_to_0_valence",
    "2nd_closest_to_0_valence_x_cube_inv_dist",
    "2nd_closest_to_1_atomic_mass",
    "2nd_closest_to_1_atomic_mass_x_cube_inv_dist",
    "2nd_closest_to_1_dist_x_atomic_mass",
    "2nd_closest_to_1_valence",
    "2nd_closest_to_1_valence_x_cube_inv_dist",
    "3rd_closest_to_0_atomic_mass",
    "3rd_closest_to_0_atomic_mass_x_cube_inv_dist",
    "3rd_closest_to_0_dist_x_atomic_mass",
    "3rd_closest_to_0_valence",
    "3rd_closest_to_0_valence_x_cube_inv_dist",
    "3rd_closest_to_1_atomic_mass",
    "3rd_closest_to_1_atomic_mass_x_cube_inv_dist",
    "3rd_closest_to_1_dist_x_atomic_mass",
    "3rd_closest_to_1_valence",
    "3rd_closest_to_1_valence_x_cube_inv_dist",
    "4th_closest_to_0_atomic_mass",
    "4th_closest_to_0_atomic_mass_x_cube_inv_dist",
    "4th_closest_to_0_dist_x_atomic_mass",
    "4th_closest_to_0_valence",
    "4th_closest_to_0_valence_x_cube_inv_dist",
    "4th_closest_to_1_atomic_mass_x_cube_inv_dist",
    "4th_closest_to_1_dist_x_atomic_mass",
    "4th_closest_to_1_valence",
    "4th_closest_to_1_valence_x_cube_inv_dist",
    "5th_closest_to_0_atomic_mass",
    "5th_closest_to_0_atomic_mass_x_cube_inv_dist",
    "5th_closest_to_0_dist_x_atomic_mass",
    "5th_closest_to_0_valence",
    "5th_closest_to_0_valence_x_cube_inv_dist",
    "5th_closest_to_1_atomic_mass_x_cube_inv_dist",
    "5th_closest_to_1_dist_x_atomic_mass",
    "5th_closest_to_1_valence",
    "5th_closest_to_1_valence_x_cube_inv_dist",
    "6th_closest_to_0_atomic_mass",
    "6th_closest_to_0_atomic_mass_x_cube_inv_dist",
    "6th_closest_to_0_dist_x_atomic_mass",
    "6th_closest_to_0_valence_x_cube_inv_dist",
    "6th_closest_to_1_atomic_mass",
    "6th_closest_to_1_atomic_mass_x_cube_inv_dist",
    "6th_closest_to_1_dist_x_atomic_mass",
    "6th_closest_to_1_valence_x_cube_inv_dist",
    "7th_closest_to_0_atomic_mass_x_cube_inv_dist",
    "7th_closest_to_0_dist_x_atomic_mass",
    "7th_closest_to_0_valence_x_cube_inv_dist",
    "7th_closest_to_1_atomic_mass_x_cube_inv_dist",
    "7th_closest_to_1_dist_x_atomic_mass",
    "7th_closest_to_1_valence",
    "7th_closest_to_1_valence_x_cube_inv_dist",
    "8th_closest_to_0_atomic_mass_x_cube_inv_dist",
    "8th_closest_to_0_dist_x_atomic_mass",
    "8th_closest_to_0_valence_x_cube_inv_dist",
    "8th_closest_to_1_atomic_mass_x_cube_inv_dist",
    "8th_closest_to_1_dist_x_atomic_mass",
    "8th_closest_to_1_valence_x_cube_inv_dist",
    "9th_closest_to_0_atomic_mass",
    "9th_closest_to_0_atomic_mass_x_cube_inv_dist",
    "9th_closest_to_0_dist_x_atomic_mass",
    "9th_closest_to_0_valence_x_cube_inv_dist",
    "9th_closest_to_1_atomic_mass_x_cube_inv_dist",
    "9th_closest_to_1_dist_x_atomic_mass",
    "9th_closest_to_1_valence_x_cube_inv_dist",
    "N1",
    "N2",
    "NH",
    "adC1",
    "adC2",
    "adC3",
    "adC4",
    "adH1",
    "adH2",
    "adN1",
    "adN2",
    "angle_0_10th0_1",
    "angle_0_1_2nd1",
    "angle_0_1_3rd1",
    "angle_0_1_4th1",
    "angle_0_1_5th1",
    "angle_0_1_closest1",
    "angle_0_2nd0_1",
    "angle_0_3rd0_1",
    "angle_0_3rd1_1",
    "angle_0_4th0_1",
    "angle_0_4th1_1",
    "angle_0_5th0_1",
    "angle_0_6th0_1",
    "angle_0_6th1_1",
    "angle_0_7th0_1",
    "angle_0_8th0_1",
    "angle_0_8th1_1",
    "angle_0_9th0_1",
    "angle_1_0_10th0",
    "angle_1_0_10th1",
    "angle_1_0_11th0",
    "angle_1_0_11th1",
    "angle_1_0_2nd0",
    "angle_1_0_3rd0",
    "angle_1_0_4th0",
    "angle_1_0_5th0",
    "angle_1_0_6th0",
    "angle_1_0_6th1",
    "angle_1_0_7th0",
    "angle_1_0_7th1",
    "angle_1_0_8th0",
    "angle_1_0_8th1",
    "angle_1_0_9th0",
    "angle_1_0_9th1",
    "angle_clos_0_2nd",
    "angle_clos_1_2nd",
    "atom1_valence",
    "atomic_mass_not_0_max",
    "atomic_mass_not_1_max",
    "atomic_mass_not_1_mean",
    "atomic_mass_not_1_std",
    "closest_to_0_atomic_mass_x_cube_inv_dist",
    "closest_to_0_dist_x_atomic_mass",
    "closest_to_0_spin_multiplicity",
    "closest_to_0_valence",
    "closest_to_0_valence_x_cube_inv_dist",
    "closest_to_1_atomic_mass_x_cube_inv_dist",
    "closest_to_1_dist_x_atomic_mass",
    "closest_to_1_valence_x_cube_inv_dist",
    "coulomb_H.x",
    "coulomb_H.y",
    "dist_to_0_max",
    "dist_to_0_min",
    "dist_to_1_max",
    "dist_to_1_min",
    "distance",
    "distance_10th_closest_to_0",
    "distance_10th_closest_to_1",
    "distance_10th_closest_to_1_cube_inverse",
    "distance_2nd_closest_to_0",
    "distance_2nd_closest_to_0_cube_inverse",
    "distance_2nd_closest_to_1",
    "distance_2nd_closest_to_1_cube_inverse",
    "distance_3rd_closest_to_0",
    "distance_3rd_closest_to_0_cube_inverse",
    "distance_3rd_closest_to_1",
    "distance_3rd_closest_to_1_cube_inverse",
    "distance_4th_closest_to_0",
    "distance_4th_closest_to_0_cube_inverse",
    "distance_4th_closest_to_1",
    "distance_4th_closest_to_1_cube_inverse",
    "distance_5th_closest_to_0",
    "distance_5th_closest_to_0_cube_inverse",
    "distance_5th_closest_to_1",
    "distance_5th_closest_to_1_cube_inverse",
    "distance_6th_closest_to_0",
    "distance_6th_closest_to_0_cube_inverse",
    "distance_6th_closest_to_1",
    "distance_6th_closest_to_1_cube_inverse",
    "distance_7th_closest_to_1",
    "distance_7th_closest_to_1_cube_inverse",
    "distance_8th_closest_to_1",
    "distance_8th_closest_to_1_cube_inverse",
    "distance_9th_closest_to_0",
    "distance_9th_closest_to_1",
    "distance_9th_closest_to_1_cube_inverse",
    "distance_closest_to_0",
    "distance_closest_to_0_cube_inverse",
    "distance_closest_to_1",
    "distance_closest_to_1_cube_inverse",
    "feat_acsf_g2_C_[1, 2]_atom0",
    "feat_acsf_g2_C_[1, 2]_atom1",
    "feat_acsf_g2_C_[1, 6]_atom0",
    "feat_acsf_g2_C_[1, 6]_atom1",
    "feat_acsf_g2_H_[0.01, 6]_atom1",
    "feat_acsf_g2_H_[0.1, 2]_atom1",
    "feat_acsf_g2_H_[0.1, 6]_atom1",
    "feat_acsf_g2_H_[1, 2]_atom0",
    "feat_acsf_g2_H_[1, 2]_atom1",
    "feat_acsf_g2_H_[1, 6]_atom0",
    "feat_acsf_g2_H_[1, 6]_atom1",
    "feat_acsf_g2_N_[0.01, 2]_atom0",
    "feat_acsf_g2_N_[1, 2]_atom1",
    "feat_acsf_g2_N_[1, 6]_atom1",
    "feat_acsf_g2_O_[1, 2]_atom0",
    "feat_acsf_g2_O_[1, 2]_atom1",
    "feat_acsf_g2_O_[1, 6]_atom0",
    "feat_acsf_g2_O_[1, 6]_atom1",
    "feat_acsf_g4_C_C_[0.01, 4, -1]_atom0",
    "feat_acsf_g4_C_C_[0.01, 4, -1]_atom1",
    "feat_acsf_g4_C_C_[0.01, 4, 1]_atom0",
    "feat_acsf_g4_C_C_[0.01, 4, 1]_atom1",
    "feat_acsf_g4_C_C_[0.1, 4, -1]_atom0",
    "feat_acsf_g4_C_C_[0.1, 4, -1]_atom1",
    "feat_acsf_g4_C_C_[0.1, 4, 1]_atom1",
    "feat_acsf_g4_C_C_[1, 4, -1]_atom0",
    "feat_acsf_g4_C_C_[1, 4, -1]_atom1",
    "feat_acsf_g4_C_C_[1, 4, 1]_atom0",
    "feat_acsf_g4_C_C_[1, 4, 1]_atom1",
    "feat_acsf_g4_C_H_[0.1, 4, -1]_atom0",
    "feat_acsf_g4_C_H_[0.1, 4, -1]_atom1",
    "feat_acsf_g4_C_H_[0.1, 4, 1]_atom0",
    "feat_acsf_g4_C_H_[0.1, 4, 1]_atom1",
    "feat_acsf_g4_C_H_[1, 4, -1]_atom0",
    "feat_acsf_g4_C_H_[1, 4, -1]_atom1",
    "feat_acsf_g4_C_H_[1, 4, 1]_atom0",
    "feat_acsf_g4_C_H_[1, 4, 1]_atom1",
    "feat_acsf_g4_H_H_[0.01, 4, -1]_atom0",
    "feat_acsf_g4_H_H_[0.01, 4, -1]_atom1",
    "feat_acsf_g4_H_H_[0.1, 4, -1]_atom0",
    "feat_acsf_g4_H_H_[0.1, 4, -1]_atom1",
    "feat_acsf_g4_H_H_[0.1, 4, 1]_atom0",
    "feat_acsf_g4_H_H_[0.1, 4, 1]_atom1",
    "feat_acsf_g4_H_H_[1, 4, -1]_atom0",
    "feat_acsf_g4_H_H_[1, 4, -1]_atom1",
    "feat_acsf_g4_H_H_[1, 4, 1]_atom0",
    "feat_acsf_g4_H_H_[1, 4, 1]_atom1",
    "feat_acsf_g4_N_C_[0.01, 4, -1]_atom0",
    "feat_acsf_g4_N_C_[0.1, 4, -1]_atom0",
    "feat_acsf_g4_N_C_[0.1, 4, -1]_atom1",
    "feat_acsf_g4_N_C_[0.1, 4, 1]_atom0",
    "feat_acsf_g4_N_C_[1, 4, -1]_atom0",
    "feat_acsf_g4_N_C_[1, 4, -1]_atom1",
    "feat_acsf_g4_N_C_[1, 4, 1]_atom0",
    "feat_acsf_g4_N_C_[1, 4, 1]_atom1",
    "feat_acsf_g4_N_H_[0.1, 4, 1]_atom1",
    "feat_acsf_g4_N_H_[1, 4, -1]_atom0",
    "feat_acsf_g4_N_H_[1, 4, -1]_atom1",
    "feat_acsf_g4_N_H_[1, 4, 1]_atom0",
    "feat_acsf_g4_N_H_[1, 4, 1]_atom1",
    "feat_acsf_g4_N_N_[0.01, 4, 1]_atom0",
    "feat_acsf_g4_N_N_[1, 4, -1]_atom1",
    "feat_acsf_g4_O_C_[0.01, 4, -1]_atom0",
    "feat_acsf_g4_O_C_[0.01, 4, -1]_atom1",
    "feat_acsf_g4_O_C_[0.01, 4, 1]_atom0",
    "feat_acsf_g4_O_C_[0.1, 4, -1]_atom0",
    "feat_acsf_g4_O_C_[0.1, 4, -1]_atom1",
    "feat_acsf_g4_O_C_[0.1, 4, 1]_atom1",
    "feat_acsf_g4_O_C_[1, 4, -1]_atom0",
    "feat_acsf_g4_O_C_[1, 4, -1]_atom1",
    "feat_acsf_g4_O_C_[1, 4, 1]_atom0",
    "feat_acsf_g4_O_C_[1, 4, 1]_atom1",
    "feat_acsf_g4_O_H_[0.01, 4, -1]_atom1",
    "feat_acsf_g4_O_H_[0.1, 4, -1]_atom0",
    "feat_acsf_g4_O_H_[0.1, 4, -1]_atom1",
    "feat_acsf_g4_O_H_[0.1, 4, 1]_atom0",
    "feat_acsf_g4_O_H_[0.1, 4, 1]_atom1",
    "feat_acsf_g4_O_H_[1, 4, -1]_atom0",
    "feat_acsf_g4_O_H_[1, 4, -1]_atom1",
    "feat_acsf_g4_O_H_[1, 4, 1]_atom0",
    "feat_acsf_g4_O_H_[1, 4, 1]_atom1",
    "feat_acsf_g4_O_N_[0.1, 4, -1]_atom1",
    "feat_acsf_g4_O_N_[0.1, 4, 1]_atom1",
    "feat_acsf_g4_O_N_[1, 4, -1]_atom0",
    "feat_acsf_g4_O_N_[1, 4, -1]_atom1",
    "feat_acsf_g4_O_N_[1, 4, 1]_atom0",
    "feat_acsf_g4_O_O_[0.1, 4, -1]_atom0",
    "feat_acsf_g4_O_O_[0.1, 4, -1]_atom1",
    "feat_acsf_g4_O_O_[1, 4, -1]_atom0",
    "feat_acsf_g4_O_O_[1, 4, -1]_atom1",
    "inv_dist0E",
    "inv_dist0R",
    "inv_dist1",
    "inv_dist1E",
    "inv_dist1R",
    "inv_distP",
    "inv_distPE",
    "inv_distPR",
    "linkM0",
    "linkM1",
    "linkN",
    "max_molecule_atom_0_dist_xyz",
    "max_molecule_atom_1_dist_xyz",
    "mean_molecule_atom_0_dist_xyz",
    "mean_molecule_atom_1_dist_xyz",
    "min_molecule_atom_0_dist_xyz",
    "min_molecule_atom_1_dist_xyz",
    "sd_molecule_atom_1_dist_xyz",
    "tor_ang_2leftleft_count",
    "tor_ang_2leftleft_max",
    "tor_ang_2leftleft_mean",
    "tor_ang_2leftleft_min",
    "val_not_0_mean",
    "val_not_0_min",
    "val_not_0_std",
    "val_not_1_mean",
    "val_not_1_std",
    "yukawa_C.x",
    "yukawa_H.x",
    "yukawa_H.y",
    "yukawa_N.x",
    "yukawa_O.x",
    "dist_C_0_x",
    "dist_C_1_x",
    "dist_C_2_x",
    "dist_C_3_x",
    "dist_C_4_x",
    "dist_F_0_x",
    "dist_F_1_x",
    "dist_F_2_x",
    "dist_F_3_x",
    "dist_F_4_x",
    "dist_H_0_x",
    "dist_H_1_x",
    "dist_H_2_x",
    "dist_H_3_x",
    "dist_H_4_x",
    "dist_N_0_x",
    "dist_N_1_x",
    "dist_N_2_x",
    "dist_N_3_x",
    "dist_N_4_x",
    "dist_O_0_x",
    "dist_O_1_x",
    "dist_O_2_x",
    "dist_O_3_x",
    "dist_O_4_x",
    "dist_C_0_y",
    "dist_C_1_y",
    "dist_C_2_y",
    "dist_C_3_y",
    "dist_C_4_y",
    "dist_F_0_y",
    "dist_F_1_y",
    "dist_F_2_y",
    "dist_F_3_y",
    "dist_F_4_y",
    "dist_H_0_y",
    "dist_H_1_y",
    "dist_H_2_y",
    "dist_H_3_y",
    "dist_H_4_y",
    "dist_N_0_y",
    "dist_N_1_y",
    "dist_N_2_y",
    "dist_N_3_y",
    "dist_N_4_y",
    "dist_O_0_y",
    "dist_O_1_y",
    "dist_O_2_y",
    "dist_O_3_y",
    "dist_O_4_y",
    "dist",
    "dist_inv2",
    "distance_closest_0",
    "distance_closest_1",
    "distance_farthest_0",
    "distance_farthest_1",
    "molecule_atom_index_0_dist_mean",
    "molecule_atom_index_0_dist_mean_diff",
    "molecule_atom_index_0_dist_min",
    "molecule_atom_index_0_dist_min_diff",
    "molecule_atom_index_0_dist_std",
    "molecule_atom_index_1_dist_mean",
    "molecule_atom_index_1_dist_mean_diff",
    "molecule_atom_index_1_dist_min",
    "molecule_atom_index_1_dist_min_diff",
    "molecule_atom_index_1_dist_std",
    "molecule_type_dist_mean",
    "molecule_type_dist_mean_diff",
    "rc_A",
    "rc_B",
    "rc_C",
    "mu",
    "alpha",
    "homo",
    "lumo",
    "gap",
    "zpve",
    "Cv",
    "freqs_min",
    "freqs_max",
    "freqs_mean",
    "mulliken_min",
    "mulliken_max",
    "mulliken_atom_0",
    "mulliken_atom_1",
]
M058 = [
    "11th_closest_to_1_exact_mass",
    "13th_closest_to_0_spin_multiplicity",
    "13th_closest_to_1_exact_mass",
    "15th_closest_to_1",
    "15th_closest_to_1_exact_mass",
    "16th_closest_to_1_spin_multiplicity",
    "17th_closest_to_1_spin_multiplicity",
    "17th_closest_to_1_spin_multiplicity_x_cube_inv_dist",
    "18th_closest_to_0",
    "18th_closest_to_0_spin_multiplicity_x_cube_inv_dist",
    "21st_closest_to_0_spin_multiplicity",
    "21st_closest_to_1_spin_multiplicity_x_cube_inv_dist",
    "22nd_closest_to_0_exact_mass",
    "22nd_closest_to_0_spin_multiplicity",
    "22nd_closest_to_0_spin_multiplicity_x_cube_inv_dist",
    "23rd_closest_to_1_exact_mass",
    "23rd_closest_to_1_spin_multiplicity_x_cube_inv_dist",
    "23rd_closest_to_1_valence",
    "2nd_closest_to_0_exact_mass",
    "2nd_closest_to_0_valence",
    "2nd_closest_to_0_valence_x_cube_inv_dist",
    "2nd_closest_to_1_exact_mass",
    "2nd_closest_to_1_valence",
    "2nd_closest_to_1_valence_x_cube_inv_dist",
    "3rd_closest_to_0_exact_mass",
    "3rd_closest_to_0_valence",
    "3rd_closest_to_0_valence_x_cube_inv_dist",
    "3rd_closest_to_1",
    "3rd_closest_to_1_exact_mass",
    "3rd_closest_to_1_valence",
    "3rd_closest_to_1_valence_x_cube_inv_dist",
    "4th_closest_to_0",
    "4th_closest_to_0_exact_mass",
    "4th_closest_to_0_valence_x_cube_inv_dist",
    "4th_closest_to_1_exact_mass",
    "4th_closest_to_1_valence",
    "4th_closest_to_1_valence_x_cube_inv_dist",
    "5th_closest_to_0_exact_mass",
    "5th_closest_to_0_valence",
    "5th_closest_to_0_valence_x_cube_inv_dist",
    "5th_closest_to_1_exact_mass",
    "5th_closest_to_1_valence",
    "5th_closest_to_1_valence_x_cube_inv_dist",
    "6th_closest_to_1_spin_multiplicity",
    "6th_closest_to_1_valence",
    "7th_closest_to_0_valence",
    "7th_closest_to_0_valence_x_cube_inv_dist",
    "8th_closest_to_0_spin_multiplicity",
    "9th_closest_to_0_exact_mass",
    "9th_closest_to_0_spin_multiplicity",
    "9th_closest_to_1_valence",
    "N1",
    "N2",
    "a0_nb_degree",
    "a0_nb_hybridization",
    "a0_nb_inring",
    "a0_nb_inring3",
    "a0_nb_inring5",
    "a0_nb_inring6",
    "a0_nb_inring7",
    "a0_nb_nb_c",
    "a0_nb_nb_h",
    "a0_nb_nb_n",
    "a1_degree",
    "a1_hybridization",
    "a1_inring",
    "a1_inring3",
    "a1_inring4",
    "a1_inring5",
    "a1_inring6",
    "a1_nb_h",
    "a1_nb_hybridization",
    "a1_nb_inring5",
    "a1_nb_n",
    "adC1",
    "adC2",
    "adC3",
    "adC4",
    "adH1",
    "adN1",
    "adN2",
    "adN4",
    "angle_0_1_2nd1",
    "angle_0_1_3rd1",
    "angle_0_1_4th1",
    "angle_0_1_5th1",
    "angle_0_2nd0_1",
    "angle_0_2nd1_1",
    "angle_0_3rd0_1",
    "angle_0_3rd1_1",
    "angle_0_4th0_1",
    "angle_0_4th1_1",
    "angle_0_6th0_1",
    "angle_0_7th1_1",
    "angle_1_0_11th1",
    "angle_1_0_2nd0",
    "angle_1_0_3rd0",
    "angle_1_0_4th0",
    "angle_1_0_5th0",
    "angle_1_0_6th0",
    "angle_1_0_6th1",
    "angle_clos_0_2nd",
    "angle_clos_1_2nd",
    "atom1_valence",
    "atom_index_1.1",
    "closest_to_0_spin_multiplicity",
    "closest_to_0_valence",
    "closest_to_0_valence_x_cube_inv_dist",
    "closest_to_1_valence_x_cube_inv_dist",
    "dist",
    "dist_H_0_x",
    "dist_H_1_x",
    "dist_H_2_y",
    "dist_O_1_x",
    "dist_inv2",
    "dist_to_0_min",
    "dist_to_1_min",
    "dist_xyz",
    "distance",
    "distance_10th_closest_to_0",
    "distance_12th_closest_to_1",
    "distance_13th_closest_to_0",
    "distance_15th_closest_to_1_cube_inverse",
    "distance_2nd_closest_to_0",
    "distance_2nd_closest_to_0_cube_inverse",
    "distance_2nd_closest_to_1",
    "distance_2nd_closest_to_1_cube_inverse",
    "distance_3rd_closest_to_0",
    "distance_3rd_closest_to_0_cube_inverse",
    "distance_3rd_closest_to_1",
    "distance_3rd_closest_to_1_cube_inverse",
    "distance_4th_closest_to_0",
    "distance_4th_closest_to_0_cube_inverse",
    "distance_4th_closest_to_1",
    "distance_4th_closest_to_1_cube_inverse",
    "distance_5th_closest_to_0",
    "distance_5th_closest_to_0_cube_inverse",
    "distance_5th_closest_to_1",
    "distance_5th_closest_to_1_cube_inverse",
    "distance_6th_closest_to_0",
    "distance_6th_closest_to_0_cube_inverse",
    "distance_6th_closest_to_1",
    "distance_6th_closest_to_1_cube_inverse",
    "distance_7th_closest_to_0",
    "distance_7th_closest_to_1_cube_inverse",
    "distance_8th_closest_to_0",
    "distance_8th_closest_to_0_cube_inverse",
    "distance_9th_closest_to_0",
    "distance_9th_closest_to_0_cube_inverse",
    "distance_9th_closest_to_1",
    "distance_closest_0",
    "distance_closest_1",
    "distance_closest_to_0",
    "distance_closest_to_0_cube_inverse",
    "distance_closest_to_1",
    "distance_closest_to_1_cube_inverse",
    "distance_farthest_0",
    "distance_farthest_1",
    "feat_acsf_g2_C_[0.01, 6]_atom1",
    "feat_acsf_g2_C_[1, 2]_atom0",
    "feat_acsf_g2_C_[1, 2]_atom1",
    "feat_acsf_g2_C_[1, 6]_atom0",
    "feat_acsf_g2_H_[1, 2]_atom1",
    "feat_acsf_g2_N_[0.1, 2]_atom1",
    "feat_acsf_g2_N_[1, 2]_atom0",
    "feat_acsf_g2_N_[1, 2]_atom1",
    "feat_acsf_g2_O_[0.01, 2]_atom0",
    "feat_acsf_g2_O_[0.01, 6]_atom0",
    "feat_acsf_g2_O_[1, 2]_atom0",
    "feat_acsf_g2_O_[1, 2]_atom1",
    "feat_acsf_g2_O_[1, 6]_atom1",
    "feat_acsf_g4_C_C_[0.01, 4, -1]_atom0",
    "feat_acsf_g4_C_C_[0.01, 4, -1]_atom1",
    "feat_acsf_g4_C_C_[0.01, 4, 1]_atom1",
    "feat_acsf_g4_C_C_[0.1, 4, -1]_atom0",
    "feat_acsf_g4_C_C_[0.1, 4, -1]_atom1",
    "feat_acsf_g4_C_C_[0.1, 4, 1]_atom0",
    "feat_acsf_g4_C_C_[0.1, 4, 1]_atom1",
    "feat_acsf_g4_C_C_[1, 4, -1]_atom0",
    "feat_acsf_g4_C_C_[1, 4, -1]_atom1",
    "feat_acsf_g4_C_C_[1, 4, 1]_atom0",
    "feat_acsf_g4_C_C_[1, 4, 1]_atom1",
    "feat_acsf_g4_C_H_[0.01, 4, -1]_atom1",
    "feat_acsf_g4_C_H_[0.1, 4, -1]_atom0",
    "feat_acsf_g4_C_H_[0.1, 4, -1]_atom1",
    "feat_acsf_g4_C_H_[0.1, 4, 1]_atom0",
    "feat_acsf_g4_C_H_[1, 4, -1]_atom0",
    "feat_acsf_g4_C_H_[1, 4, -1]_atom1",
    "feat_acsf_g4_C_H_[1, 4, 1]_atom0",
    "feat_acsf_g4_C_H_[1, 4, 1]_atom1",
    "feat_acsf_g4_F_F_[0.01, 4, -1]_atom1",
    "feat_acsf_g4_H_H_[0.1, 4, -1]_atom0",
    "feat_acsf_g4_H_H_[0.1, 4, -1]_atom1",
    "feat_acsf_g4_H_H_[1, 4, -1]_atom0",
    "feat_acsf_g4_H_H_[1, 4, -1]_atom1",
    "feat_acsf_g4_H_H_[1, 4, 1]_atom0",
    "feat_acsf_g4_H_H_[1, 4, 1]_atom1",
    "feat_acsf_g4_N_C_[0.01, 4, -1]_atom0",
    "feat_acsf_g4_N_C_[0.01, 4, -1]_atom1",
    "feat_acsf_g4_N_C_[0.1, 4, -1]_atom0",
    "feat_acsf_g4_N_C_[0.1, 4, -1]_atom1",
    "feat_acsf_g4_N_C_[1, 4, -1]_atom0",
    "feat_acsf_g4_N_C_[1, 4, -1]_atom1",
    "feat_acsf_g4_N_C_[1, 4, 1]_atom0",
    "feat_acsf_g4_N_C_[1, 4, 1]_atom1",
    "feat_acsf_g4_N_H_[0.01, 4, -1]_atom0",
    "feat_acsf_g4_N_H_[0.1, 4, -1]_atom0",
    "feat_acsf_g4_N_H_[0.1, 4, -1]_atom1",
    "feat_acsf_g4_N_H_[1, 4, -1]_atom0",
    "feat_acsf_g4_N_H_[1, 4, 1]_atom0",
    "feat_acsf_g4_N_H_[1, 4, 1]_atom1",
    "feat_acsf_g4_N_N_[0.1, 4, -1]_atom0",
    "feat_acsf_g4_N_N_[1, 4, -1]_atom0",
    "feat_acsf_g4_N_N_[1, 4, 1]_atom0",
    "feat_acsf_g4_N_N_[1, 4, 1]_atom1",
    "feat_acsf_g4_O_C_[0.01, 4, -1]_atom0",
    "feat_acsf_g4_O_C_[0.01, 4, 1]_atom0",
    "feat_acsf_g4_O_C_[0.1, 4, -1]_atom0",
    "feat_acsf_g4_O_C_[0.1, 4, -1]_atom1",
    "feat_acsf_g4_O_C_[0.1, 4, 1]_atom0",
    "feat_acsf_g4_O_C_[1, 4, -1]_atom0",
    "feat_acsf_g4_O_C_[1, 4, -1]_atom1",
    "feat_acsf_g4_O_C_[1, 4, 1]_atom0",
    "feat_acsf_g4_O_C_[1, 4, 1]_atom1",
    "feat_acsf_g4_O_H_[0.01, 4, -1]_atom0",
    "feat_acsf_g4_O_H_[0.1, 4, -1]_atom0",
    "feat_acsf_g4_O_H_[0.1, 4, -1]_atom1",
    "feat_acsf_g4_O_H_[0.1, 4, 1]_atom0",
    "feat_acsf_g4_O_H_[1, 4, -1]_atom1",
    "feat_acsf_g4_O_H_[1, 4, 1]_atom0",
    "feat_acsf_g4_O_H_[1, 4, 1]_atom1",
    "feat_acsf_g4_O_N_[0.01, 4, -1]_atom0",
    "feat_acsf_g4_O_N_[0.1, 4, -1]_atom0",
    "feat_acsf_g4_O_N_[0.1, 4, 1]_atom0",
    "feat_acsf_g4_O_N_[1, 4, -1]_atom0",
    "feat_acsf_g4_O_N_[1, 4, -1]_atom1",
    "feat_acsf_g4_O_N_[1, 4, 1]_atom1",
    "feat_acsf_g4_O_O_[1, 4, -1]_atom0",
    "gap",
    "inv_dist0E",
    "inv_dist0R",
    "inv_dist1",
    "inv_dist1R",
    "inv_distP",
    "inv_distPR",
    "is_bond_3rd_closest_to_1",
    "is_bond_4th_closest_to_1",
    "link0",
    "linkM0",
    "linkM1",
    "linkN",
    "max_molecule_atom_0_dist_xyz",
    "mean_molecule_atom_0_dist_xyz",
    "mean_molecule_atom_1_dist_xyz",
    "min_molecule_atom_0_dist_xyz",
    "min_molecule_atom_1_dist_xyz",
    "molecule_atom_index_0_dist_mean",
    "molecule_atom_index_0_dist_min",
    "molecule_atom_index_1_dist_mean",
    "molecule_atom_index_1_dist_mean_diff",
    "molecule_atom_index_1_dist_min",
    "molecule_atom_index_1_dist_min_diff",
    "molecule_type_dist_mean",
    "molecule_type_dist_mean_diff",
    "mu",
    "mulliken_atom_0",
    "mulliken_atom_1",
    "mulliken_min",
    "sd_molecule_atom_0_dist_xyz",
    "tor_ang_2leftleft_count",
    "val_not_0_max",
    "val_not_1_std",
    "yukawa_H.x",
    "yukawa_H.y",
    "yukawa_N.y",
]

# %%
def intersection(lst1, lst2): 
    lst3 = [value for value in lst1 if value in lst2] 
    return lst3

# %%
intercect = intersection(M053, M058)

# %%
import numpy as np

# %%
mergedlist = sorted(np.unique(M053+M058))

# %%
import pandas as pd

# %%
tr_FE019 = pd.read_parquet('../data/FE019/FE019-train-1JHN.parquet')
tr_FE020 = pd.read_parquet('../data/FE022/FE022-train-1JHN.parquet')
tr_FE021 = pd.read_parquet('../data/FE021/FE021-train-1JHN.parquet')

# %%
tr_FE020[['id','scalar_coupling_constant']].head()
# Out:
#     id  scalar_coupling_constant
# 0   10                   32.6889
# 1   13                   32.6891
# 2   15                   32.6905
# 3   97                   55.5252
# 4  101                   54.7359

# %%
tr_FE019.shape
# Out:
# (43363, 1227)

# %%
tr_FE020.shape
# Out:
# (43363, 378)

# %%
tr_FE021.shape
# Out:
# (43363, 275)

# %%
tr_FE019[['a0_nb_nb_c', 'a1_inring5', 'a1_nb_h', 'a1_inring', 'a0_nb_inring3',
          'a0_nb_hybridization', 'a0_nb_inring5', 'a0_nb_nb_n', 'a1_nb_n', 'a0_nb_degree',
          'a1_nb_hybridization', 'a1_nb_inring5', 'a1_degree', 'a0_nb_nb_h', 'a1_inring6',
          'a0_nb_inring7', 'a1_inring3', 'a1_hybridization', 'a0_nb_inring6', 'a1_inring4', 'a0_nb_inring']] = tr_FE020[['a0_nb_nb_c', 'a1_inring5', 'a1_nb_h', 'a1_inring', 'a0_nb_inring3',
          'a0_nb_hybridization', 'a0_nb_inring5', 'a0_nb_nb_n', 'a1_nb_n', 'a0_nb_degree',
          'a1_nb_hybridization', 'a1_nb_inring5', 'a1_degree', 'a0_nb_nb_h', 'a1_inring6',
          'a0_nb_inring7', 'a1_inring3', 'a1_hybridization', 'a0_nb_inring6', 'a1_inring4', 'a0_nb_inring']]

# %%
tr_FE019[['id','molecule_name','atom_index_0',
          'atom_index_1','type','scalar_coupling_constant'] + mergedlist].to_parquet('../data/FE023/FE023-train-1JHN.parquet')

# %%
te_FE019 = pd.read_parquet('../data/FE019/FE019-test-1JHN.parquet')
te_FE020 = pd.read_parquet('../data/FE022/FE022-test-1JHN.parquet')
te_FE021 = pd.read_parquet('../data/FE021/FE021-test-1JHN.parquet')

# %%
te_FE019[['a0_nb_nb_c', 'a1_inring5', 'a1_nb_h', 'a1_inring', 'a0_nb_inring3',
          'a0_nb_hybridization', 'a0_nb_inring5', 'a0_nb_nb_n', 'a1_nb_n', 'a0_nb_degree',
          'a1_nb_hybridization', 'a1_nb_inring5', 'a1_degree', 'a0_nb_nb_h', 'a1_inring6',
          'a0_nb_inring7', 'a1_inring3', 'a1_hybridization', 'a0_nb_inring6', 'a1_inring4', 'a0_nb_inring']] = te_FE020[['a0_nb_nb_c', 'a1_inring5', 'a1_nb_h', 'a1_inring', 'a0_nb_inring3',
          'a0_nb_hybridization', 'a0_nb_inring5', 'a0_nb_nb_n', 'a1_nb_n', 'a0_nb_degree',
          'a1_nb_hybridization', 'a1_nb_inring5', 'a1_degree', 'a0_nb_nb_h', 'a1_inring6',
          'a0_nb_inring7', 'a1_inring3', 'a1_hybridization', 'a0_nb_inring6', 'a1_inring4', 'a0_nb_inring']]

# %%
te_FE019[['id','molecule_name','atom_index_0',
          'atom_index_1','type','scalar_coupling_constant'] + mergedlist].to_parquet('../data/FE023/FE023-test-1JHN.parquet')

# %%
te_FE019[['id','molecule_name','atom_index_0',
          'atom_index_1','type','scalar_coupling_constant'] + mergedlist]['id']
# Out:
# 0        4658203
# 1        4658207
# 2        4658212
# 3        4658216
# 4        4658303
#           ...
# 24190    7162581
# 24191    7162587
# 24192    7162656
# 24193    7162799
# 24194    7162804
# Name: id, Length: 24195, dtype: int64

# %%
FE023_tr = pd.read_parquet('../data/FE023/FE023-train-1JHN.parquet')

# %%
FE023_tr.shape
# Out:
# (43363, 485)

# %%
FE023_tr.loc[:,~FE023_tr.columns.duplicated()].shape
# Out:
# (43363, 485)

# %%
FE023_te = pd.read_parquet('../data/FE023/FE023-test-1JHN.parquet')

# %%
FE023_te.shape
# Out:
# (24195, 485)

# %%
FE023_te.loc[:,~FE023_te.columns.duplicated()].shape
# Out:
# (24195, 485)

# %%
FE023_te[['id','molecule_atom_index_1_dist_mean', 'inv_distPE', 'dist_N_4_y', 'feat_acsf_g4_N_H_[0.01, 4, -1]_atom0',
          '3rd_closest_to_1_valence', '3rd_closest_to_0_valence_x_cube_inv_dist', 'inv_distP', 'feat_acsf_g4_O_O_[0.1, 4, -1]_atom1',
          '4th_closest_to_1_valence', 'max_molecule_atom_1_dist_xyz', 'dist_F_3_x', 'a0_nb_nb_c', '3rd_closest_to_0_dist_x_atomic_mass',
          'molecule_atom_index_1_dist_std', 'distance_6th_closest_to_1_cube_inverse', 'distance_4th_closest_to_0_cube_inverse', 'feat_acsf_g4_H_H_[1, 4, 1]_atom0', '9th_closest_to_1_valence_x_cube_inv_dist', 'feat_acsf_g2_N_[1, 6]_atom1', 'feat_acsf_g4_N_H_[1, 4, -1]_atom1', 'feat_acsf_g4_O_C_[0.1, 4, -1]_atom0', 'angle_1_0_9th0', 'a1_nb_n', 'yukawa_N.y', 'feat_acsf_g4_N_N_[1, 4, 1]_atom0', 'angle_0_6th0_1', '8th_closest_to_0_dist_x_atomic_mass', 'alpha', '3rd_closest_to_1_valence_x_cube_inv_dist', 'angle_1_0_2nd0', '5th_closest_to_1_exact_mass', 'dist_O_4_y', 'distance_7th_closest_to_1', 'feat_acsf_g2_C_[1, 6]_atom0', 'feat_acsf_g4_O_N_[0.01, 4, -1]_atom0', 'feat_acsf_g4_O_C_[0.01, 4, -1]_atom1', 'angle_clos_1_2nd', 'feat_acsf_g4_O_N_[1, 4, -1]_atom0', 'a1_inring', 'feat_acsf_g2_O_[1, 6]_atom0', 'atom1_valence', 'feat_acsf_g4_N_H_[0.1, 4, -1]_atom1', 'max_molecule_atom_0_dist_xyz', 'dist_N_0_x', '7th_closest_to_1_valence', '9th_closest_to_1_dist_x_atomic_mass', 'molecule_type_dist_mean_diff', 'distance_closest_to_1', 'mulliken_atom_1', 'dist_O_3_x', 'distance_6th_closest_to_0_cube_inverse', 'adC2', 'distance_9th_closest_to_0_cube_inverse', 'feat_acsf_g4_O_H_[1, 4, -1]_atom0', 'feat_acsf_g4_O_H_[0.01, 4, -1]_atom1', '6th_closest_to_1_atomic_mass_x_cube_inv_dist', 'dist_N_1_y', 'rc_B', 'dist_to_0_min', 'val_not_0_std', 'dist_C_3_y', 'Cv', 'inv_dist0R', '12th_closest_to_0_atomic_mass_x_cube_inv_dist', 'dist_to_1_max', 'dist_H_0_x', 'angle_0_3rd0_1', '3rd_closest_to_1_atomic_mass_x_cube_inv_dist', '9th_closest_to_0_spin_multiplicity', 'dist_N_3_x', 'zpve', 'dist_F_1_x', 'distance_closest_to_1_cube_inverse', 'distance_closest_to_0_cube_inverse', '3rd_closest_to_1_atomic_mass', 'distance_10th_closest_to_1_cube_inverse', 'molecule_atom_index_0_dist_mean_diff', 'yukawa_C.x', 'feat_acsf_g4_O_N_[0.1, 4, -1]_atom1', 'atomic_mass_not_1_max', 'feat_acsf_g4_N_N_[1, 4, 1]_atom1', '4th_closest_to_1_valence_x_cube_inv_dist', '8th_closest_to_0_atomic_mass_x_cube_inv_dist', 'feat_acsf_g4_O_H_[1, 4, 1]_atom1', '3rd_closest_to_1_dist_x_atomic_mass', 'feat_acsf_g4_C_H_[0.1, 4, 1]_atom0', 'feat_acsf_g4_O_N_[1, 4, 1]_atom1', 'angle_0_2nd1_1', 'feat_acsf_g4_O_O_[1, 4, -1]_atom1', 'molecule_atom_index_1_dist_mean_diff', '8th_closest_to_0_spin_multiplicity', 'closest_to_0_atomic_mass_x_cube_inv_dist', 'mulliken_max', 'distance_closest_1', 'mulliken_atom_0', '5th_closest_to_0_dist_x_atomic_mass', 'dist_C_2_x', 'distance_5th_closest_to_0', 'rc_C', 'tor_ang_2leftleft_min', 'dist_H_4_x', '5th_closest_to_0_valence_x_cube_inv_dist', '15th_closest_to_1', 'distance_closest_0', 'feat_acsf_g4_H_H_[0.1, 4, 1]_atom0', 'feat_acsf_g2_O_[1, 6]_atom1', '9th_closest_to_0_exact_mass', '4th_closest_to_1_atomic_mass_x_cube_inv_dist', 'feat_acsf_g4_O_N_[0.1, 4, 1]_atom1', 'a1_inring6', '4th_closest_to_0_atomic_mass_x_cube_inv_dist', 'angle_0_4th0_1', 'feat_acsf_g4_N_C_[0.01, 4, -1]_atom1', '6th_closest_to_1_spin_multiplicity', 'atomic_mass_not_0_max', 'feat_acsf_g4_C_H_[0.1, 4, -1]_atom0', 'dist_C_2_y', '2nd_closest_to_0_valence', 'a1_degree', 'dist_O_1_x', 'adC4', 'dist_O_0_x', 'distance_4th_closest_to_1', 'angle_clos_0_2nd', 'angle_1_0_8th1', '3rd_closest_to_0_atomic_mass', 'angle_0_8th1_1', 'dist_to_0_max', 'closest_to_1_valence_x_cube_inv_dist', 'feat_acsf_g4_C_H_[1, 4, 1]_atom0', 'angle_0_3rd1_1', 'molecule_atom_index_1_dist_min', '3rd_closest_to_1_exact_mass', 'inv_dist0E', 'adN1', 'feat_acsf_g4_O_N_[1, 4, -1]_atom1', 'feat_acsf_g4_O_C_[0.1, 4, 1]_atom1', 'a0_nb_degree', 'feat_acsf_g4_N_N_[0.01, 4, 1]_atom0', 'a0_nb_inring7', 'distance', 'mean_molecule_atom_0_dist_xyz', 'distance_6th_closest_to_1', '4th_closest_to_0_dist_x_atomic_mass', 'dist_N_3_y', '21st_closest_to_0_spin_multiplicity', 'dist_H_2_y', 'adN4', 'feat_acsf_g4_O_C_[1, 4, 1]_atom1', '2nd_closest_to_0_atomic_mass', 'freqs_max', 'angle_0_1_2nd1', 'inv_dist1', 'dist_F_0_y', 'angle_0_7th1_1', 'dist_O_3_y', '23rd_closest_to_1_spin_multiplicity_x_cube_inv_dist', '21st_closest_to_1_spin_multiplicity_x_cube_inv_dist', 'feat_acsf_g4_N_N_[0.1, 4, -1]_atom0', 'angle_0_1_3rd1', 'feat_acsf_g4_N_C_[0.1, 4, -1]_atom1', 'feat_acsf_g4_C_C_[0.1, 4, 1]_atom0', 'N2', 'dist_C_0_y', 'yukawa_O.x', 'val_not_0_max', 'feat_acsf_g2_N_[1, 2]_atom1', 'feat_acsf_g4_C_C_[1, 4, 1]_atom1', '4th_closest_to_0_valence', '10th_closest_to_1_valence_x_cube_inv_dist', 'feat_acsf_g4_N_C_[1, 4, -1]_atom0', 'feat_acsf_g4_H_H_[1, 4, 1]_atom1', 'feat_acsf_g4_N_C_[1, 4, -1]_atom1', 'sd_molecule_atom_0_dist_xyz', '3rd_closest_to_1', '2nd_closest_to_1_dist_x_atomic_mass', 'feat_acsf_g4_N_H_[1, 4, 1]_atom0', 'distance_8th_closest_to_0_cube_inverse', '12th_closest_to_1_atomic_mass_x_cube_inv_dist', 'distance_farthest_1', 'linkN', 'distance_9th_closest_to_0', 'feat_acsf_g4_C_H_[1, 4, 1]_atom1', 'a0_nb_hybridization', 'a0_nb_inring3', 'NH', 'val_not_1_mean', 'closest_to_1_atomic_mass_x_cube_inv_dist', 'feat_acsf_g4_O_H_[1, 4, 1]_atom0', 'val_not_0_min', 'dist_C_0_x', 'feat_acsf_g4_C_C_[1, 4, -1]_atom0', 'distance_6th_closest_to_0', 'feat_acsf_g4_C_H_[0.01, 4, -1]_atom1', 'angle_1_0_6th1', '11th_closest_to_1_exact_mass', 'adC1', '2nd_closest_to_0_atomic_mass_x_cube_inv_dist', 'distance_12th_closest_to_1', 'gap', 'a0_nb_inring6', 'dist_F_3_y', 'feat_acsf_g4_N_C_[0.1, 4, -1]_atom0', '10th_closest_to_1_atomic_mass_x_cube_inv_dist', 'feat_acsf_g4_O_C_[1, 4, -1]_atom0', 'distance_4th_closest_to_0', 'inv_distPR', 'angle_0_2nd0_1', 'dist_H_2_x', 'feat_acsf_g2_N_[0.1, 2]_atom1', 'feat_acsf_g4_O_N_[0.1, 4, 1]_atom0', 'distance_5th_closest_to_0_cube_inverse', 'closest_to_1_dist_x_atomic_mass', 'angle_1_0_9th1', '9th_closest_to_0_atomic_mass', 'distance_9th_closest_to_1_cube_inverse', '5th_closest_to_1_dist_x_atomic_mass', 'feat_acsf_g4_C_C_[0.1, 4, 1]_atom1', 'molecule_atom_index_0_dist_min_diff', 'dist_C_1_y', '22nd_closest_to_0_spin_multiplicity', '7th_closest_to_0_valence_x_cube_inv_dist', 'mean_molecule_atom_1_dist_xyz', 'molecule_type_dist_mean', 'feat_acsf_g2_C_[1, 6]_atom1', 'feat_acsf_g2_H_[0.01, 6]_atom1', 'feat_acsf_g4_F_F_[0.01, 4, -1]_atom1', 'min_molecule_atom_1_dist_xyz', 'angle_0_1_4th1', 'distance_3rd_closest_to_1_cube_inverse', 'val_not_1_std', '9th_closest_to_0_dist_x_atomic_mass', 'dist_to_1_min', 'feat_acsf_g2_O_[0.01, 6]_atom0', '9th_closest_to_1_valence', 'feat_acsf_g4_N_C_[0.1, 4, 1]_atom0', 'dist_N_4_x', 'closest_to_0_valence', '8th_closest_to_1_atomic_mass_x_cube_inv_dist', 'adH1', 'angle_1_0_5th0', '5th_closest_to_1_valence', 'dist_N_2_x', 'angle_1_0_7th1', '5th_closest_to_0_exact_mass', 'distance_3rd_closest_to_0_cube_inverse', 'dist_xyz', 'dist_N_1_x', 'distance_10th_closest_to_1', 'linkM0', 'distance_15th_closest_to_1_cube_inverse', '8th_closest_to_1_dist_x_atomic_mass', '15th_closest_to_1_exact_mass', 'feat_acsf_g4_O_H_[0.1, 4, 1]_atom1', 'dist_inv2', 'atomic_mass_not_1_std', '21st_closest_to_0_atomic_mass_x_cube_inv_dist', 'homo', '8th_closest_to_1_valence_x_cube_inv_dist', 'feat_acsf_g4_O_H_[0.1, 4, -1]_atom0', 'feat_acsf_g4_O_H_[0.01, 4, -1]_atom0', '3rd_closest_to_0_atomic_mass_x_cube_inv_dist', 'dist_O_0_y', 'a1_nb_inring5', 'yukawa_H.y', 'feat_acsf_g4_H_H_[0.1, 4, -1]_atom0', 'freqs_min', 'feat_acsf_g4_O_C_[0.01, 4, 1]_atom0', 'angle_1_0_10th0', 'angle_1_0_8th0', 'feat_acsf_g2_N_[1, 2]_atom0', 'distance_2nd_closest_to_0_cube_inverse', 'feat_acsf_g2_H_[0.1, 2]_atom1', 'angle_1_0_11th1', 'atomic_mass_not_1_mean', 'feat_acsf_g2_N_[0.01, 2]_atom0', 'dist_O_4_x', 'feat_acsf_g4_C_C_[1, 4, -1]_atom1', 'feat_acsf_g4_N_H_[1, 4, -1]_atom0', 'a1_inring3', 'distance_4th_closest_to_1_cube_inverse', 'a1_inring4', '5th_closest_to_0_atomic_mass_x_cube_inv_dist', 'distance_2nd_closest_to_0', 'feat_acsf_g4_C_C_[0.01, 4, -1]_atom0', 'tor_ang_2leftleft_mean', '2nd_closest_to_1_exact_mass', 'is_bond_4th_closest_to_1', '2nd_closest_to_0_valence_x_cube_inv_dist', '3rd_closest_to_0_exact_mass', '13th_closest_to_0_spin_multiplicity', 'feat_acsf_g4_O_C_[0.01, 4, -1]_atom0', 'dist_H_3_x', 'distance_5th_closest_to_1', 'feat_acsf_g2_H_[0.1, 6]_atom1', 'angle_1_0_4th0', '6th_closest_to_1_atomic_mass', 'a0_nb_nb_h', '4th_closest_to_0_valence_x_cube_inv_dist', 'angle_0_1_closest1', 'coulomb_H.x', 'angle_0_7th0_1', '9th_closest_to_1_atomic_mass_x_cube_inv_dist', 'N1', 'yukawa_H.x', '8th_closest_to_0_valence_x_cube_inv_dist', 'closest_to_0_valence_x_cube_inv_dist', 'feat_acsf_g4_O_C_[1, 4, -1]_atom1', 'dist_N_0_y', 'feat_acsf_g4_H_H_[0.1, 4, 1]_atom1', 'lumo', 'link0', '23rd_closest_to_1_exact_mass', '2nd_closest_to_1_atomic_mass_x_cube_inv_dist', 'mulliken_min', '4th_closest_to_0', 'sd_molecule_atom_1_dist_xyz', 'angle_0_10th0_1', 'dist_C_3_x', '22nd_closest_to_0_exact_mass', 'mu', 'distance_7th_closest_to_1_cube_inverse', 'feat_acsf_g4_N_C_[1, 4, 1]_atom1', 'distance_10th_closest_to_0', '6th_closest_to_0_dist_x_atomic_mass', 'inv_dist1R', 'molecule_atom_index_1_dist_min_diff', 'angle_0_6th1_1', 'feat_acsf_g4_O_H_[0.1, 4, -1]_atom1', 'tor_ang_2leftleft_max', 'dist_F_4_x', 'feat_acsf_g4_C_C_[1, 4, 1]_atom0', '5th_closest_to_0_valence', '4th_closest_to_0_exact_mass', 'a1_hybridization', 'feat_acsf_g2_O_[0.01, 2]_atom0', '17th_closest_to_1_spin_multiplicity', '13th_closest_to_1_exact_mass', '2nd_closest_to_1_valence_x_cube_inv_dist', 'feat_acsf_g4_C_H_[1, 4, -1]_atom0', 'adH2', 'feat_acsf_g4_C_H_[0.1, 4, -1]_atom1', 'feat_acsf_g4_C_C_[0.01, 4, 1]_atom0', 'min_molecule_atom_0_dist_xyz', 'a1_inring5', 'feat_acsf_g4_O_O_[0.1, 4, -1]_atom0', '2nd_closest_to_0_dist_x_atomic_mass', '9th_closest_to_0_valence_x_cube_inv_dist', '6th_closest_to_1_valence', 'distance_closest_to_0', 'feat_acsf_g2_H_[1, 6]_atom1', 'dist_N_2_y', 'feat_acsf_g4_O_C_[0.1, 4, -1]_atom1', 'feat_acsf_g4_O_O_[1, 4, -1]_atom0', 'angle_1_0_11th0', 'dist_O_2_x', '7th_closest_to_0_valence', 'distance_8th_closest_to_1', 'angle_1_0_3rd0', 'adC3', 'dist_H_0_y', 'distance_8th_closest_to_0', 'dist_C_4_y', 'feat_acsf_g4_C_C_[0.01, 4, 1]_atom1', 'feat_acsf_g2_O_[1, 2]_atom1', 'atom_index_1.1', 'dist_O_1_y', 'a0_nb_nb_n', '4th_closest_to_0_atomic_mass', '5th_closest_to_1_valence_x_cube_inv_dist', 'feat_acsf_g4_H_H_[0.01, 4, -1]_atom1', 'feat_acsf_g4_O_H_[0.1, 4, 1]_atom0', 'dist_H_1_x', 'feat_acsf_g4_N_H_[0.1, 4, 1]_atom1', 'feat_acsf_g4_N_C_[0.01, 4, -1]_atom0', 'distance_9th_closest_to_1', '17th_closest_to_1_spin_multiplicity_x_cube_inv_dist', 'val_not_0_mean', 'feat_acsf_g4_C_C_[0.01, 4, -1]_atom1', 'feat_acsf_g4_H_H_[0.1, 4, -1]_atom1', 'dist_F_2_x', 'distance_farthest_0', 'distance_2nd_closest_to_1', 'feat_acsf_g4_C_C_[0.1, 4, -1]_atom1', 'angle_0_9th0_1', 'feat_acsf_g4_C_H_[0.1, 4, 1]_atom1', 'is_bond_3rd_closest_to_1', '6th_closest_to_0_valence_x_cube_inv_dist', 'closest_to_0_spin_multiplicity', 'distance_7th_closest_to_0', 'freqs_mean', 'distance_13th_closest_to_0', '3rd_closest_to_0_valence', '4th_closest_to_1_dist_x_atomic_mass', 'distance_3rd_closest_to_1', 'angle_0_4th1_1', 'dist_C_1_x', 'dist_O_2_y', '18th_closest_to_0_spin_multiplicity_x_cube_inv_dist', 'rc_A', 'dist_F_2_y', 'feat_acsf_g4_O_C_[0.1, 4, 1]_atom0', '7th_closest_to_0_dist_x_atomic_mass', '4th_closest_to_1_exact_mass', 'tor_ang_2leftleft_count', '7th_closest_to_1_atomic_mass_x_cube_inv_dist', 'dist_F_4_y', 'feat_acsf_g4_H_H_[1, 4, -1]_atom1', 'feat_acsf_g4_O_N_[1, 4, 1]_atom0', 'feat_acsf_g4_N_C_[1, 4, 1]_atom0', 'feat_acsf_g2_C_[1, 2]_atom0', 'angle_0_5th0_1', 'feat_acsf_g4_C_H_[1, 4, -1]_atom1', 'feat_acsf_g2_H_[1, 6]_atom0', 'feat_acsf_g4_O_H_[1, 4, -1]_atom1', '14th_closest_to_1_atomic_mass_x_cube_inv_dist', 'molecule_atom_index_0_dist_min', '10th_closest_to_0_valence_x_cube_inv_dist', 'distance_3rd_closest_to_0', 'feat_acsf_g4_C_C_[0.1, 4, -1]_atom0', '18th_closest_to_0', '13th_closest_to_1_atomic_mass_x_cube_inv_dist', 'dist_C_4_x', 'distance_2nd_closest_to_1_cube_inverse', '2nd_closest_to_0_exact_mass', '6th_closest_to_1_dist_x_atomic_mass', 'dist_F_0_x', 'feat_acsf_g4_N_N_[1, 4, -1]_atom0', '6th_closest_to_0_atomic_mass', '5th_closest_to_0_atomic_mass', 'feat_acsf_g2_O_[1, 2]_atom0', 'angle_1_0_7th0', 'distance_5th_closest_to_1_cube_inverse', 'yukawa_N.x', 'linkM1', 'feat_acsf_g4_O_C_[1, 4, 1]_atom0', 'feat_acsf_g4_H_H_[0.01, 4, -1]_atom0', 'molecule_atom_index_0_dist_std', 'feat_acsf_g4_H_H_[1, 4, -1]_atom0', 'feat_acsf_g2_C_[1, 2]_atom1', 'feat_acsf_g2_H_[1, 2]_atom1', '2nd_closest_to_1_atomic_mass', '7th_closest_to_0_atomic_mass_x_cube_inv_dist', '22nd_closest_to_0_spin_multiplicity_x_cube_inv_dist', 'a1_nb_hybridization', '6th_closest_to_1_valence_x_cube_inv_dist', '10th_closest_to_0_atomic_mass_x_cube_inv_dist', 'a1_nb_h', 'dist_H_3_y', 'molecule_atom_index_0_dist_mean', '9th_closest_to_0_atomic_mass_x_cube_inv_dist', 'feat_acsf_g4_N_H_[0.1, 4, -1]_atom0', 'angle_0_8th0_1', 'adN2', '2nd_closest_to_1_valence', 'coulomb_H.y', 'distance_8th_closest_to_1_cube_inverse', 'feat_acsf_g4_N_H_[1, 4, 1]_atom1', 'a0_nb_inring5', 'feat_acsf_g2_C_[0.01, 6]_atom1', 'angle_1_0_6th0', 'angle_0_1_5th1', 'a0_nb_inring', 'dist_H_4_y', '5th_closest_to_1_atomic_mass_x_cube_inv_dist', 'dist', 'feat_acsf_g2_H_[1, 2]_atom0', 'feat_acsf_g4_O_N_[0.1, 4, -1]_atom0', '16th_closest_to_1_spin_multiplicity', '7th_closest_to_1_valence_x_cube_inv_dist', 'closest_to_0_dist_x_atomic_mass', 'angle_1_0_10th1', 'dist_H_1_y', 'feat_acsf_g4_N_N_[1, 4, -1]_atom1', '7th_closest_to_1_dist_x_atomic_mass', '23rd_closest_to_1_valence', 'dist_F_1_y', 'inv_dist1E', '6th_closest_to_0_atomic_mass_x_cube_inv_dist']]
# Out:
#             id  molecule_atom_index_1_dist_mean  inv_distPE  dist_N_4_y  \
# 0      4658203                         1.008873    1.655253         0.0
# 1      4658207                         1.008873    1.903579         0.0
# 2      4658212                         1.008875    1.655257         0.0
# 3      4658216                         1.008875    1.903586         0.0
# 4      4658303                         1.006898    1.835447         0.0
# ...        ...                              ...         ...         ...
# 24190  7162581                         1.016232    1.455040         0.0
# 24191  7162587                         1.016232    1.654186         0.0
# 24192  7162656                         1.015315    1.500637         0.0
# 24193  7162799                         1.016326    1.536658         0.0
# 24194  7162804                         1.016326    1.726908         0.0
#
#        feat_acsf_g4_N_H_[0.01, 4, -1]_atom0  3rd_closest_to_1_valence  \
# ...

# %% [markdown]
# # Grouping CV by Molecule

# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_parquet('../data/FE005-train.parquet')
test = pd.read_parquet('../data/FE005-test.parquet')

# %%
train.head()
# Out:
#    atom_index_0  atom_index_1  type  scalar_coupling_constant     fc        ...         molecule_type_dist_min  molecule_type_dist_std  molecule_type_dist_std_diff  id     molecule_name
# 0             1             0  1JHC                     84.80  83.00        ...                          1.092                0.000003                       -1.092   0  dsgdb9nsd_000001
# 1             1             2  2JHH                    -11.26 -11.03        ...                          1.783                0.000014                       -1.783   1  dsgdb9nsd_000001
# 2             1             3  2JHH                    -11.26 -11.03        ...                          1.783                0.000014                       -1.783   2  dsgdb9nsd_000001
# 3             1             4  2JHH                    -11.26 -11.03        ...                          1.783                0.000014                       -1.783   3  dsgdb9nsd_000001
# 4             2             0  1JHC                     84.80  83.00        ...                          1.092                0.000003                       -1.092   4  dsgdb9nsd_000001
#
# [5 rows x 83 columns]

# %%
test.head()
# Out:
#    atom_index_0  atom_index_1  type  atom_index_x  atom_0        ...         molecule_type_dist_min  molecule_type_dist_std  molecule_type_dist_std_diff       id     molecule_name
# 0             2             0  2JHC             2       0        ...                         2.2620                     0.0                      -2.2620  4658147  dsgdb9nsd_000004
# 1             2             1  1JHC             2       0        ...                         1.0625                     0.0                      -1.0625  4658148  dsgdb9nsd_000004
# 2             2             3  3JHH             2       0        ...                         3.3240                     NaN                          NaN  4658149  dsgdb9nsd_000004
# 3             3             0  1JHC             3       0        ...                         1.0625                     0.0                      -1.0625  4658150  dsgdb9nsd_000004
# 4             3             1  2JHC             3       0        ...                         2.2620                     0.0                      -2.2620  4658151  dsgdb9nsd_000004
#
# [5 rows x 81 columns]

# %%
structures = pd.read_csv('../input/structures.csv')

# %%
structures.head()
# Out:
#       molecule_name  atom_index atom         x         y         z
# 0  dsgdb9nsd_000001           0    C -0.012698  1.085804  0.008001
# 1  dsgdb9nsd_000001           1    H  0.002150 -0.006031  0.001976
# 2  dsgdb9nsd_000001           2    H  1.011731  1.463751  0.000277
# 3  dsgdb9nsd_000001           3    H -0.540815  1.447527 -0.876644
# 4  dsgdb9nsd_000001           4    H -0.523814  1.437933  0.906397

# %%
traincsv = pd.read_csv('../input/train.csv')

# %%
traincsv.head()
# Out:
#    id     molecule_name  atom_index_0  atom_index_1  type  scalar_coupling_constant
# 0   0  dsgdb9nsd_000001             1             0  1JHC                   84.8076
# 1   1  dsgdb9nsd_000001             1             2  2JHH                  -11.2570
# 2   2  dsgdb9nsd_000001             1             3  2JHH                  -11.2548
# 3   3  dsgdb9nsd_000001             1             4  2JHH                  -11.2543
# 4   4  dsgdb9nsd_000001             2             0  1JHC                   84.8074

# %%
len(traincsv['molecule_name'].unique())
# Out:
# 85003

# %%
len(traincsv)
# Out:
# 4658147

# %%
train.head()
# Out:
#    atom_index_0  atom_index_1  type  scalar_coupling_constant     fc        ...         molecule_type_dist_min  molecule_type_dist_std  molecule_type_dist_std_diff  id     molecule_name
# 0             1             0  1JHC                     84.80  83.00        ...                          1.092                0.000003                       -1.092   0  dsgdb9nsd_000001
# 1             1             2  2JHH                    -11.26 -11.03        ...                          1.783                0.000014                       -1.783   1  dsgdb9nsd_000001
# 2             1             3  2JHH                    -11.26 -11.03        ...                          1.783                0.000014                       -1.783   2  dsgdb9nsd_000001
# 3             1             4  2JHH                    -11.26 -11.03        ...                          1.783                0.000014                       -1.783   3  dsgdb9nsd_000001
# 4             2             0  1JHC                     84.80  83.00        ...                          1.092                0.000003                       -1.092   4  dsgdb9nsd_000001
#
# [5 rows x 83 columns]

# %%
test.head()
# Out:
#    atom_index_0  atom_index_1  type  atom_index_x  atom_0        ...         molecule_type_dist_min  molecule_type_dist_std  molecule_type_dist_std_diff       id     molecule_name
# 0             2             0  2JHC             2       0        ...                         2.2620                     0.0                      -2.2620  4658147  dsgdb9nsd_000004
# 1             2             1  1JHC             2       0        ...                         1.0625                     0.0                      -1.0625  4658148  dsgdb9nsd_000004
# 2             2             3  3JHH             2       0        ...                         3.3240                     NaN                          NaN  4658149  dsgdb9nsd_000004
# 3             3             0  1JHC             3       0        ...                         1.0625                     0.0                      -1.0625  4658150  dsgdb9nsd_000004
# 4             3             1  2JHC             3       0        ...                         2.2620                     0.0                      -2.2620  4658151  dsgdb9nsd_000004
#
# [5 rows x 81 columns]

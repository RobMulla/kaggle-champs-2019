# %% [markdown]
# # Evaluation of Model Results
# ## Model M043

# %%
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
import os
import pprint
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

test = pd.read_csv('../input/test.csv')

# %%
tracking = pd.read_csv('../tracking/tracking.csv')
BEST_PUBLIC_RUN_ID = tracking.loc[tracking['lb_score'] == tracking['lb_score'].min()]['run_id'].values[0]
BEST_PUBLIC_SCORE = tracking.loc[tracking['lb_score'] == tracking['lb_score'].min()]['lb_score'].values[0]
print('------------------------------------------------------')
print('Currently the best public LB score is model {} with a score of {:.4f}'.format(BEST_PUBLIC_RUN_ID,
                                                                                     BEST_PUBLIC_SCORE))
print('------------------------------------------------------')
tracking.dropna(subset=['gml_oof_score']).sort_values('gml_oof_score').head()
# Out:
# ------------------------------------------------------
# Currently the best public LB score is model 0708_1639 with a score of -1.6420
# ------------------------------------------------------
#        run_id model_number eval_metric  n_estimators  early_stopping_rounds  random_state  n_threads    ...      2JHHcv_f2  1JHNcv_f1 1JHNcv_f2  3JHHcv_f1  3JHHcv_f2  1JHCcv_f1  1JHCcv_f2
# 34  0710_2124         M043         MAE      500000.0                  500.0         529.0       48.0    ...       0.137902   0.390914  0.361851   0.154694   0.155712   0.510383   0.514468
# 31  0708_1639         M040         MAE      500000.0                  500.0         529.0       16.0    ...            NaN        NaN       NaN        NaN        NaN        NaN        NaN
# 28  0706_2029         M037         MAE      500000.0                   50.0         529.0       16.0    ...            NaN        NaN       NaN        NaN        NaN        NaN        NaN
# 30  0708_1415         M039         MAE       50000.0                  500.0         529.0       16.0    ...            NaN        NaN       NaN        NaN        NaN        NaN        NaN
# 27  0705_2317         M036         MAE      300000.0                   50.0         529.0       16.0    ...            NaN        NaN       NaN        NaN        NaN        NaN        NaN
#
# [5 rows x 120 columns]

# %%
tracking.loc[tracking['model_number'] == 'M043']
# Out:
#        run_id model_number eval_metric  n_estimators  early_stopping_rounds  random_state  n_threads    ...      2JHHcv_f2  1JHNcv_f1 1JHNcv_f2  3JHHcv_f1  3JHHcv_f2  1JHCcv_f1  1JHCcv_f2
# 34  0710_2124         M043         MAE      500000.0                  500.0         529.0       48.0    ...       0.137902   0.390914  0.361851   0.154694   0.155712   0.510383   0.514468
#
# [1 rows x 120 columns]

# %%
RUN_ID = '-1.5582'
# MODEL_NO = 'M033'
sub_file = [x for x in os.listdir('../submissions/') if RUN_ID in x][0]
fi_file = [x for x in os.listdir('../fi/') if '0710_2124' in x][0]
oof_file = [x for x in os.listdir('../oof') if RUN_ID in x][0]
# print(sub_file)
# Read in files for new RUN_ID
sub = pd.read_csv(f'../submissions/{sub_file}')
oof = pd.read_csv(f'../oof/{oof_file}')
fi = pd.read_csv(f'../fi/{fi_file}')

# Read in files for best RUN_ID
bsub_file = [x for x in os.listdir('../submissions/') if BEST_PUBLIC_RUN_ID in x][0]
#bfi_file = [x for x in os.listdir('../fi/') if BEST_PUBLIC_RUN_ID in x][0]
boof_file = [x for x in os.listdir('../oof') if BEST_PUBLIC_RUN_ID in x][0]
bsub = pd.read_csv(f'../submissions/{bsub_file}')
boof = pd.read_csv(f'../oof/{boof_file}')
# bfi = pd.read_csv(f'../fi/{bfi_file}')

# %% [markdown]
# ## Features with no importance

# %%
thresh = 0.01
fi_mean = fi.groupby('feature').mean()
no_importance_features = fi_mean.loc[fi_mean['importance'] <= thresh].index.tolist()
print('Features with no importance at all')
pprint.pprint(no_importance_features)
# Out:
# Features with no importance at all
# ['10th_closest_to_0_atomic_mass',
#  '10th_closest_to_0_spin_multiplicity',
#  '10th_closest_to_0_valence',
#  '10th_closest_to_1_spin_multiplicity',
#  '13th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '13th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '14th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '14th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '15th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '15th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '16th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '16th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '17th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '17th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '18th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '18th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '19th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '19th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '20th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '20th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '21st_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '21st_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '22nd_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '22nd_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '23rd_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '23rd_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '24th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '24th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '25th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '25th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '26th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '26th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '27th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '27th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '28th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '28th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '6th_closest_to_1_valence',
#  '7th_closest_to_0_valence',
#  '7th_closest_to_1_atomic_mass',
#  '8th_closest_to_0_atomic_mass',
#  '8th_closest_to_0_valence',
#  '8th_closest_to_1_atomic_mass',
#  '9th_closest_to_0_atomic_mass',
#  '9th_closest_to_0_spin_multiplicity',
#  '9th_closest_to_0_valence',
#  '9th_closest_to_1_atomic_mass',
#  '9th_closest_to_1_spin_multiplicity',
#  '9th_closest_to_1_valence',
#  'N2',
#  'NC',
#  'NO',
#  'angle_0_10th1_1',
#  'atomic_mass_not_0_mean',
#  'atomic_mass_not_0_min',
#  'atomic_mass_not_0_std',
#  'atomic_mass_not_1_mean',
#  'atomic_mass_not_1_min',
#  'atomic_mass_not_1_std',
#  'coulomb_C.x',
#  'coulomb_C.y',
#  'coulomb_H.x',
#  'coulomb_H.y',
#  'coulomb_N.x',
#  'coulomb_N.y',
#  'coulomb_O.x',
#  'coulomb_O.y',
#  'distN1',
#  'dist_to_0_std',
#  'dist_to_1_mean',
#  'dist_to_1_std',
#  'distance_10th_closest_to_0_cube_inverse',
#  'distance_9th_closest_to_0_cube_inverse',
#  'feat_acsf_g1_C_10.0_atom0',
#  'feat_acsf_g1_C_10.0_atom1',
#  'feat_acsf_g1_F_10.0_atom0',
#  'feat_acsf_g1_F_10.0_atom1',
#  'feat_acsf_g1_H_10.0_atom1',
#  'feat_acsf_g1_N_10.0_atom0',
#  'feat_acsf_g1_N_10.0_atom1',
#  'feat_acsf_g1_O_10.0_atom0',
#  'feat_acsf_g1_O_10.0_atom1',
#  'feat_acsf_g2_C_[0.01, 2]_atom0',
#  'feat_acsf_g2_C_[0.01, 2]_atom1',
#  'feat_acsf_g2_C_[0.01, 6]_atom0',
#  'feat_acsf_g2_C_[0.01, 6]_atom1',
#  'feat_acsf_g2_C_[0.1, 2]_atom0',
#  'feat_acsf_g2_C_[0.1, 2]_atom1',
#  'feat_acsf_g2_C_[0.1, 6]_atom0',
#  'feat_acsf_g2_C_[0.1, 6]_atom1',
#  'feat_acsf_g2_F_[0.01, 2]_atom0',
#  'feat_acsf_g2_F_[0.01, 2]_atom1',
#  'feat_acsf_g2_F_[0.01, 6]_atom0',
#  'feat_acsf_g2_F_[0.01, 6]_atom1',
#  'feat_acsf_g2_F_[0.1, 2]_atom0',
#  'feat_acsf_g2_F_[0.1, 2]_atom1',
#  'feat_acsf_g2_F_[0.1, 6]_atom0',
#  'feat_acsf_g2_F_[0.1, 6]_atom1',
#  'feat_acsf_g2_F_[1, 2]_atom0',
#  'feat_acsf_g2_F_[1, 2]_atom1',
#  'feat_acsf_g2_F_[1, 6]_atom0',
#  'feat_acsf_g2_F_[1, 6]_atom1',
#  'feat_acsf_g2_H_[0.01, 2]_atom1',
#  'feat_acsf_g2_H_[0.01, 6]_atom0',
#  'feat_acsf_g2_H_[0.01, 6]_atom1',
#  'feat_acsf_g2_H_[0.1, 2]_atom1',
#  'feat_acsf_g2_H_[0.1, 6]_atom0',
#  'feat_acsf_g2_H_[0.1, 6]_atom1',
#  'feat_acsf_g2_N_[0.01, 2]_atom0',
#  'feat_acsf_g2_N_[0.01, 2]_atom1',
#  'feat_acsf_g2_N_[0.01, 6]_atom0',
#  'feat_acsf_g2_N_[0.01, 6]_atom1',
#  'feat_acsf_g2_N_[0.1, 2]_atom0',
#  'feat_acsf_g2_N_[0.1, 2]_atom1',
#  'feat_acsf_g2_N_[0.1, 6]_atom0',
#  'feat_acsf_g2_N_[0.1, 6]_atom1',
#  'feat_acsf_g2_O_[0.01, 2]_atom0',
#  'feat_acsf_g2_O_[0.01, 2]_atom1',
#  'feat_acsf_g2_O_[0.01, 6]_atom0',
#  'feat_acsf_g2_O_[0.01, 6]_atom1',
#  'feat_acsf_g2_O_[0.1, 2]_atom0',
#  'feat_acsf_g2_O_[0.1, 2]_atom1',
#  'feat_acsf_g2_O_[0.1, 6]_atom1',
#  'feat_acsf_g4_C_C_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_C_H_[0.01, 4, -1]_atom0',
#  'feat_acsf_g4_C_H_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_F_C_[0.01, 4, -1]_atom0',
#  'feat_acsf_g4_F_C_[0.01, 4, -1]_atom1',
#  'feat_acsf_g4_F_C_[0.01, 4, 1]_atom0',
#  'feat_acsf_g4_F_C_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_F_C_[0.1, 4, -1]_atom0',
#  'feat_acsf_g4_F_C_[0.1, 4, -1]_atom1',
#  'feat_acsf_g4_F_C_[0.1, 4, 1]_atom0',
#  'feat_acsf_g4_F_C_[0.1, 4, 1]_atom1',
#  'feat_acsf_g4_F_C_[1, 4, -1]_atom0',
#  'feat_acsf_g4_F_C_[1, 4, -1]_atom1',
#  'feat_acsf_g4_F_C_[1, 4, 1]_atom0',
#  'feat_acsf_g4_F_C_[1, 4, 1]_atom1',
#  'feat_acsf_g4_F_F_[0.01, 4, -1]_atom0',
#  'feat_acsf_g4_F_F_[0.01, 4, -1]_atom1',
#  'feat_acsf_g4_F_F_[0.01, 4, 1]_atom0',
#  'feat_acsf_g4_F_F_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_F_F_[0.1, 4, -1]_atom0',
#  'feat_acsf_g4_F_F_[0.1, 4, -1]_atom1',
#  'feat_acsf_g4_F_F_[0.1, 4, 1]_atom0',
#  'feat_acsf_g4_F_F_[0.1, 4, 1]_atom1',
#  'feat_acsf_g4_F_F_[1, 4, -1]_atom0',
#  'feat_acsf_g4_F_F_[1, 4, -1]_atom1',
#  'feat_acsf_g4_F_F_[1, 4, 1]_atom0',
#  'feat_acsf_g4_F_F_[1, 4, 1]_atom1',
#  'feat_acsf_g4_F_H_[0.01, 4, -1]_atom0',
#  'feat_acsf_g4_F_H_[0.01, 4, -1]_atom1',
#  'feat_acsf_g4_F_H_[0.01, 4, 1]_atom0',
#  'feat_acsf_g4_F_H_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_F_H_[0.1, 4, -1]_atom0',
#  'feat_acsf_g4_F_H_[0.1, 4, -1]_atom1',
#  'feat_acsf_g4_F_H_[0.1, 4, 1]_atom0',
#  'feat_acsf_g4_F_H_[0.1, 4, 1]_atom1',
#  'feat_acsf_g4_F_H_[1, 4, -1]_atom0',
#  'feat_acsf_g4_F_H_[1, 4, -1]_atom1',
#  'feat_acsf_g4_F_H_[1, 4, 1]_atom0',
#  'feat_acsf_g4_F_H_[1, 4, 1]_atom1',
#  'feat_acsf_g4_F_N_[0.01, 4, -1]_atom0',
#  'feat_acsf_g4_F_N_[0.01, 4, -1]_atom1',
#  'feat_acsf_g4_F_N_[0.01, 4, 1]_atom0',
#  'feat_acsf_g4_F_N_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_F_N_[0.1, 4, -1]_atom0',
#  'feat_acsf_g4_F_N_[0.1, 4, -1]_atom1',
#  'feat_acsf_g4_F_N_[0.1, 4, 1]_atom0',
#  'feat_acsf_g4_F_N_[0.1, 4, 1]_atom1',
#  'feat_acsf_g4_F_N_[1, 4, -1]_atom0',
#  'feat_acsf_g4_F_N_[1, 4, -1]_atom1',
#  'feat_acsf_g4_F_N_[1, 4, 1]_atom0',
#  'feat_acsf_g4_F_N_[1, 4, 1]_atom1',
#  'feat_acsf_g4_F_O_[0.01, 4, -1]_atom0',
#  'feat_acsf_g4_F_O_[0.01, 4, -1]_atom1',
#  'feat_acsf_g4_F_O_[0.01, 4, 1]_atom0',
#  'feat_acsf_g4_F_O_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_F_O_[0.1, 4, -1]_atom0',
#  'feat_acsf_g4_F_O_[0.1, 4, -1]_atom1',
#  'feat_acsf_g4_F_O_[0.1, 4, 1]_atom0',
#  'feat_acsf_g4_F_O_[0.1, 4, 1]_atom1',
#  'feat_acsf_g4_F_O_[1, 4, -1]_atom0',
#  'feat_acsf_g4_F_O_[1, 4, -1]_atom1',
#  'feat_acsf_g4_F_O_[1, 4, 1]_atom0',
#  'feat_acsf_g4_F_O_[1, 4, 1]_atom1',
#  'feat_acsf_g4_H_H_[0.01, 4, 1]_atom0',
#  'feat_acsf_g4_H_H_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_N_C_[0.01, 4, -1]_atom0',
#  'feat_acsf_g4_N_C_[0.01, 4, -1]_atom1',
#  'feat_acsf_g4_N_C_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_N_H_[0.01, 4, -1]_atom0',
#  'feat_acsf_g4_N_H_[0.01, 4, 1]_atom0',
#  'feat_acsf_g4_N_H_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_N_H_[0.1, 4, -1]_atom1',
#  'feat_acsf_g4_N_N_[0.01, 4, -1]_atom1',
#  'feat_acsf_g4_N_N_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_N_N_[0.1, 4, -1]_atom0',
#  'feat_acsf_g4_N_N_[0.1, 4, -1]_atom1',
#  'feat_acsf_g4_N_N_[0.1, 4, 1]_atom0',
#  'feat_acsf_g4_N_N_[0.1, 4, 1]_atom1',
#  'feat_acsf_g4_O_C_[0.01, 4, 1]_atom0',
#  'feat_acsf_g4_O_C_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_O_H_[0.01, 4, -1]_atom1',
#  'feat_acsf_g4_O_H_[0.01, 4, 1]_atom0',
#  'feat_acsf_g4_O_H_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_O_N_[0.01, 4, -1]_atom1',
#  'feat_acsf_g4_O_N_[0.01, 4, 1]_atom0',
#  'feat_acsf_g4_O_N_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_O_N_[0.1, 4, -1]_atom1',
#  'feat_acsf_g4_O_O_[0.01, 4, -1]_atom0',
#  'feat_acsf_g4_O_O_[0.01, 4, -1]_atom1',
#  'feat_acsf_g4_O_O_[0.01, 4, 1]_atom0',
#  'feat_acsf_g4_O_O_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_O_O_[0.1, 4, 1]_atom0',
#  'feat_acsf_g4_O_O_[0.1, 4, 1]_atom1',
#  'feat_acsf_g4_O_O_[1, 4, -1]_atom1',
#  'linkM1',
#  'mol_wt',
#  'num_bonds',
#  'tor_ang_2leftleft_mean',
#  'val_not_0_min',
#  'val_not_1_max',
#  'val_not_1_min',
#  'yukawa_C.x',
#  'yukawa_C.y',
#  'yukawa_N.y']

# %% [markdown]
# ## Feature with no importance by type

# %%
fi_minus_non_imp = fi.loc[~fi['feature'].isin(no_importance_features)]
thresh = 0.005
for i, d in fi_minus_non_imp.groupby('type'):
    d_mean = d.groupby('feature').mean()
    bad_cols = d_mean.loc[d_mean['importance'] <= thresh].index
    print('================== Type {} =================='.format(i))
    print([x for x in bad_cols])
# Out:
# ================== Type 1JHC ==================
# ['NH', 'angle_0_closest0_1', 'angle_1_0_closest0', 'closest_to_0_atomic_mass', 'closest_to_1_atomic_mass', 'closest_to_1_atomic_number', 'closest_to_1_spin_multiplicity', 'closest_to_1_spin_multiplicity_x_cube_inv_dist', 'closest_to_1_valence', 'feat_acsf_g2_H_[0.01, 2]_atom0', 'feat_acsf_g2_H_[0.1, 2]_atom0', 'feat_acsf_g2_N_[1, 2]_atom0', 'feat_acsf_g4_C_C_[0.01, 4, 1]_atom0', 'feat_acsf_g4_N_H_[0.01, 4, -1]_atom1', 'feat_acsf_g4_N_N_[0.01, 4, -1]_atom0', 'feat_acsf_g4_N_N_[0.01, 4, 1]_atom0', 'feat_acsf_g4_N_N_[1, 4, -1]_atom0', 'feat_acsf_g4_O_C_[0.1, 4, 1]_atom0', 'feat_acsf_g4_O_N_[0.01, 4, -1]_atom0', 'feat_acsf_g4_O_N_[0.1, 4, -1]_atom0', 'yukawa_N.x', 'yukawa_O.x', 'yukawa_O.y']
# ================== Type 1JHN ==================
# ['10th_closest_to_0_atomic_mass_x_cube_inv_dist', '10th_closest_to_1_atomic_mass_x_cube_inv_dist', '12th_closest_to_0_atomic_mass_x_cube_inv_dist', '12th_closest_to_1_atomic_mass_x_cube_inv_dist', '5th_closest_to_1_atomic_mass', '6th_closest_to_0_valence', '7th_closest_to_0_atomic_mass', '8th_closest_to_0_atomic_mass_x_cube_inv_dist', '8th_closest_to_0_dist_x_atomic_mass', '8th_closest_to_0_valence_x_cube_inv_dist', '8th_closest_to_1_dist_x_atomic_mass', '9th_closest_to_0_atomic_mass_x_cube_inv_dist', '9th_closest_to_0_dist_x_atomic_mass', '9th_closest_to_0_valence_x_cube_inv_dist', 'adN2', 'angle_0_11th0_1', 'angle_0_1_closest1', 'angle_0_5th1_1', 'angle_0_6th1_1', 'angle_0_7th0_1', 'angle_0_7th1_1', 'angle_0_8th0_1', 'angle_0_8th1_1', 'angle_0_9th0_1', 'angle_0_9th1_1', 'angle_0_closest0_1', 'angle_0_closest1_1', 'angle_1_0_10th1', 'angle_1_0_11th0', 'angle_1_0_11th1', 'angle_1_0_9th0', 'angle_1_0_closest0', 'atomic_mass_not_0_max', 'closest_to_0_atomic_mass', 'closest_to_0_spin_multiplicity_x_cube_inv_dist', 'closest_to_1_atomic_mass', 'closest_to_1_atomic_number', 'closest_to_1_spin_multiplicity', 'closest_to_1_spin_multiplicity_x_cube_inv_dist', 'closest_to_1_valence', 'dist_to_0_max', 'dist_to_1_max', 'distance_10th_closest_to_1_cube_inverse', 'distance_5th_closest_to_1_cube_inverse', 'distance_7th_closest_to_0_cube_inverse', 'distance_7th_closest_to_1_cube_inverse', 'distance_8th_closest_to_0_cube_inverse', 'distance_8th_closest_to_1_cube_inverse', 'distance_9th_closest_to_0', 'distance_9th_closest_to_1_cube_inverse', 'feat_acsf_g1_H_10.0_atom0', 'feat_acsf_g2_H_[0.1, 2]_atom0', 'feat_acsf_g2_N_[1, 6]_atom0', 'feat_acsf_g2_O_[0.1, 6]_atom0', 'feat_acsf_g2_O_[1, 2]_atom1', 'feat_acsf_g2_O_[1, 6]_atom0', 'feat_acsf_g2_O_[1, 6]_atom1', 'feat_acsf_g4_C_C_[0.01, 4, -1]_atom0', 'feat_acsf_g4_C_C_[0.01, 4, 1]_atom0', 'feat_acsf_g4_C_C_[0.1, 4, 1]_atom1', 'feat_acsf_g4_C_H_[0.01, 4, 1]_atom0', 'feat_acsf_g4_C_H_[0.1, 4, 1]_atom1', 'feat_acsf_g4_H_H_[0.01, 4, -1]_atom1', 'feat_acsf_g4_H_H_[0.1, 4, 1]_atom1', 'feat_acsf_g4_N_C_[0.1, 4, 1]_atom1', 'feat_acsf_g4_N_C_[1, 4, 1]_atom1', 'feat_acsf_g4_N_H_[0.01, 4, -1]_atom1', 'feat_acsf_g4_O_H_[0.1, 4, 1]_atom1', 'feat_acsf_g4_O_O_[0.1, 4, -1]_atom0', 'feat_acsf_g4_O_O_[1, 4, -1]_atom0', 'feat_acsf_g4_O_O_[1, 4, 1]_atom0', 'feat_acsf_g4_O_O_[1, 4, 1]_atom1', 'inv_dist0', 'inv_distPE', 'mulliken_charge_0', 'mulliken_charge_1', 'mulliken_charge_2nd_closest_0', 'mulliken_charge_2nd_closest_1', 'mulliken_charge_closest_0', 'mulliken_charge_closest_1', 'val_not_0_mean', 'yukawa_O.y']
# ================== Type 2JHH ==================
# ['2nd_closest_to_0_atomic_mass', '2nd_closest_to_0_valence', '2nd_closest_to_1_atomic_mass', '2nd_closest_to_1_valence', '4th_closest_to_1_atomic_mass', '8th_closest_to_1_valence', 'angle_0_2nd1_1', 'angle_0_8th1_1', 'angle_0_9th1_1', 'atom1_valence', 'closest_to_0_atomic_mass', 'closest_to_0_spin_multiplicity', 'closest_to_0_spin_multiplicity_x_cube_inv_dist', 'closest_to_1_atomic_mass', 'closest_to_1_atomic_number', 'closest_to_1_spin_multiplicity', 'closest_to_1_spin_multiplicity_x_cube_inv_dist', 'distance_9th_closest_to_0', 'distance_9th_closest_to_1', 'feat_acsf_g1_H_10.0_atom0', 'feat_acsf_g2_H_[0.01, 2]_atom0', 'feat_acsf_g4_C_H_[0.01, 4, 1]_atom0', 'feat_acsf_g4_N_C_[0.01, 4, 1]_atom0', 'feat_acsf_g4_N_H_[0.01, 4, -1]_atom1', 'feat_acsf_g4_N_N_[1, 4, -1]_atom0', 'feat_acsf_g4_N_N_[1, 4, -1]_atom1', 'inv_dist1E', 'mulliken_charge_0', 'mulliken_charge_2nd_closest_0', 'mulliken_charge_2nd_closest_1', 'mulliken_charge_closest_0', 'mulliken_charge_closest_1', 'val_not_0_max', 'yukawa_N.x', 'yukawa_O.x', 'yukawa_O.y']
# ================== Type 2JHN ==================
# ['3rd_closest_to_1_atomic_mass', '4th_closest_to_0_valence', '4th_closest_to_1_atomic_mass', '4th_closest_to_1_valence', '5th_closest_to_0_valence', '5th_closest_to_1_atomic_mass', '5th_closest_to_1_valence', '6th_closest_to_0_atomic_mass', '6th_closest_to_0_valence', '7th_closest_to_0_atomic_mass', '7th_closest_to_1_valence', '8th_closest_to_1_valence', 'NH', 'adN2', 'angle_0_6th1_1', 'angle_0_7th1_1', 'angle_0_8th1_1', 'angle_0_9th1_1', 'closest_to_0_spin_multiplicity_x_cube_inv_dist', 'closest_to_1_atomic_mass', 'closest_to_1_atomic_number', 'closest_to_1_spin_multiplicity', 'distance_10th_closest_to_0', 'distance_10th_closest_to_1', 'distance_7th_closest_to_1', 'distance_8th_closest_to_0', 'distance_9th_closest_to_1', 'feat_acsf_g1_H_10.0_atom0', 'feat_acsf_g2_H_[0.01, 2]_atom0', 'feat_acsf_g2_H_[0.1, 2]_atom0', 'feat_acsf_g2_N_[1, 6]_atom1', 'feat_acsf_g2_O_[0.1, 6]_atom0', 'feat_acsf_g2_O_[1, 2]_atom0', 'feat_acsf_g2_O_[1, 6]_atom1', 'feat_acsf_g4_C_H_[0.01, 4, 1]_atom0', 'feat_acsf_g4_H_H_[0.01, 4, -1]_atom1', 'feat_acsf_g4_H_H_[0.1, 4, 1]_atom0', 'feat_acsf_g4_H_H_[0.1, 4, 1]_atom1', 'feat_acsf_g4_N_C_[0.01, 4, 1]_atom0', 'feat_acsf_g4_N_C_[0.1, 4, 1]_atom1', 'feat_acsf_g4_N_N_[0.01, 4, -1]_atom0', 'feat_acsf_g4_N_N_[0.01, 4, 1]_atom0', 'feat_acsf_g4_N_N_[1, 4, -1]_atom1', 'feat_acsf_g4_N_N_[1, 4, 1]_atom1', 'feat_acsf_g4_O_C_[0.1, 4, -1]_atom0', 'feat_acsf_g4_O_O_[0.1, 4, -1]_atom0', 'feat_acsf_g4_O_O_[0.1, 4, -1]_atom1', 'feat_acsf_g4_O_O_[1, 4, -1]_atom0', 'feat_acsf_g4_O_O_[1, 4, 1]_atom0', 'feat_acsf_g4_O_O_[1, 4, 1]_atom1', 'mulliken_charge_0', 'mulliken_charge_1', 'mulliken_charge_2nd_closest_0', 'mulliken_charge_2nd_closest_1', 'mulliken_charge_closest_0', 'mulliken_charge_closest_1', 'val_not_0_max', 'val_not_0_std', 'yukawa_N.x', 'yukawa_O.x', 'yukawa_O.y']
# ================== Type 3JHC ==================
# ['4th_closest_to_0_atomic_mass', '4th_closest_to_1_atomic_mass', '5th_closest_to_0_valence', '6th_closest_to_0_atomic_mass', '7th_closest_to_0_atomic_mass', '7th_closest_to_1_valence', '8th_closest_to_1_valence', 'NH', 'angle_0_8th1_1', 'angle_0_9th1_1', 'closest_to_0_atomic_mass', 'closest_to_0_valence', 'closest_to_1_valence', 'dist_to_1_min', 'feat_acsf_g1_H_10.0_atom0', 'feat_acsf_g2_H_[0.01, 2]_atom0', 'feat_acsf_g2_H_[0.1, 2]_atom0', 'feat_acsf_g4_N_H_[0.01, 4, -1]_atom1', 'feat_acsf_g4_N_N_[0.01, 4, -1]_atom0', 'feat_acsf_g4_N_N_[0.01, 4, 1]_atom0', 'mulliken_charge_0', 'mulliken_charge_2nd_closest_1', 'mulliken_charge_closest_0', 'mulliken_charge_closest_1', 'val_not_0_max']
# ================== Type 3JHH ==================
# ['4th_closest_to_0_atomic_mass', '4th_closest_to_0_valence', '4th_closest_to_1_atomic_mass', '5th_closest_to_0_atomic_mass', '5th_closest_to_0_valence', '5th_closest_to_1_atomic_mass', '5th_closest_to_1_valence', '6th_closest_to_0_atomic_mass', '6th_closest_to_0_valence', '6th_closest_to_1_atomic_mass', '7th_closest_to_0_atomic_mass', '7th_closest_to_1_valence', '8th_closest_to_1_valence', 'N1', 'NH', 'angle_0_7th1_1', 'angle_0_8th1_1', 'angle_0_9th1_1', 'atom1_valence', 'closest_to_0_spin_multiplicity', 'closest_to_1_spin_multiplicity', 'dist_to_0_mean', 'feat_acsf_g1_H_10.0_atom0', 'feat_acsf_g2_H_[0.01, 2]_atom0', 'feat_acsf_g2_H_[0.1, 2]_atom0', 'feat_acsf_g2_N_[1, 6]_atom0', 'feat_acsf_g2_N_[1, 6]_atom1', 'feat_acsf_g4_C_H_[0.01, 4, -1]_atom1', 'feat_acsf_g4_C_H_[0.01, 4, 1]_atom0', 'feat_acsf_g4_H_H_[0.01, 4, -1]_atom1', 'feat_acsf_g4_N_C_[0.1, 4, -1]_atom0', 'feat_acsf_g4_N_C_[0.1, 4, -1]_atom1', 'feat_acsf_g4_N_H_[0.01, 4, -1]_atom1', 'feat_acsf_g4_N_N_[0.01, 4, -1]_atom0', 'feat_acsf_g4_N_N_[0.01, 4, 1]_atom0', 'feat_acsf_g4_N_N_[1, 4, -1]_atom0', 'feat_acsf_g4_N_N_[1, 4, -1]_atom1', 'feat_acsf_g4_O_N_[0.01, 4, -1]_atom0', 'feat_acsf_g4_O_N_[0.1, 4, -1]_atom0', 'mulliken_charge_0', 'mulliken_charge_1', 'mulliken_charge_2nd_closest_0', 'mulliken_charge_2nd_closest_1', 'mulliken_charge_closest_0', 'mulliken_charge_closest_1', 'val_not_0_max', 'val_not_1_std', 'yukawa_H.y', 'yukawa_N.x', 'yukawa_O.y']

# %%
for i, d in fi_minus_non_imp.groupby('type'):
    plt.figure(figsize=(16, 30));
    sns.barplot(x="importance", y="feature", data=d.sort_values(by="importance", ascending=False));
    plt.title('{} - LGB Features (avg over folds)'.format(i))
    plt.show()

# %% [markdown]
# # Compare Submission Files

# %%
sub = sub.sort_values('id').reset_index(drop=True)
bsub = bsub.sort_values('id').reset_index(drop=True)

# %%
sub['type'] = test['type']
bsub['type'] = test['type']

# %%
for i, d in sub.groupby('type'):
    d['scalar_coupling_constant'].plot(kind='hist', figsize=(15, 3), title=i, bins=1000, alpha=0.3)
    # also plot best sub
    d_bsub = bsub.loc[bsub['type'] == i]
    d_bsub['scalar_coupling_constant'].plot(kind='hist', figsize=(15, 3), title=i, bins=1000, alpha=0.3)
    #d_oof = oof.loc[oof['type'] == i]
    #d_oof['scalar_coupling_constant'].plot(kind='hist', figsize=(15, 3), title=i, bins=1000, alpha=0.3)
    plt.show()

# %%
sub['bscalar_coupling_constant'] = bsub['scalar_coupling_constant']
# Scatter plot of submission
for i, d in sub.groupby('type'):
    d.plot(x='bscalar_coupling_constant', y='scalar_coupling_constant', kind='scatter', figsize=(5, 5), title=i)

# %% [markdown]
# # Compare OOF

# %%
for i, d in oof.groupby('type'):
    d['scalar_coupling_constant'].plot(kind='hist', figsize=(15, 3), title=i, bins=1000, alpha=0.3)
    # also plot best sub
    d_boof = boof.loc[boof['type'] == i]
    d_boof['scalar_coupling_constant'].plot(kind='hist', figsize=(15, 3), title=i, bins=1000, alpha=0.3)
    plt.show()

# %% [markdown]
# # Update Leaderboard score

# %%
# LB_SCORE = -1.642
# tracking = pd.read_csv('../tracking/tracking.csv')
# tracking.loc[tracking['run_id'] == RUN_ID, 'lb_score'] = LB_SCORE
# tracking.to_csv('../tracking/tracking.csv', index=False)

# %% [markdown]
# # 3JHC
# Good Features

# %%
jhc3 = fi.loc[fi['type'] == '3JHC'].groupby('feature').mean()

# %%
thresh = 0.01
important_feats = jhc3.loc[jhc3['importance'] >= thresh].index.tolist()
pprint.pprint(important_feats)
# Out:
# ['10th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '10th_closest_to_0_valence_x_cube_inv_dist',
#  '10th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '10th_closest_to_1_valence_x_cube_inv_dist',
#  '12th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '12th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '13th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '13th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '14th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '14th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '15th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '15th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '16th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '16th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '2nd_closest_to_0_atomic_mass',
#  '2nd_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '2nd_closest_to_0_dist_x_atomic_mass',
#  '2nd_closest_to_0_valence',
#  '2nd_closest_to_0_valence_x_cube_inv_dist',
#  '2nd_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '2nd_closest_to_1_dist_x_atomic_mass',
#  '2nd_closest_to_1_valence',
#  '2nd_closest_to_1_valence_x_cube_inv_dist',
#  '3rd_closest_to_0_atomic_mass',
#  '3rd_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '3rd_closest_to_0_dist_x_atomic_mass',
#  '3rd_closest_to_0_valence',
#  '3rd_closest_to_0_valence_x_cube_inv_dist',
#  '3rd_closest_to_1_atomic_mass',
#  '3rd_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '3rd_closest_to_1_dist_x_atomic_mass',
#  '3rd_closest_to_1_valence',
#  '3rd_closest_to_1_valence_x_cube_inv_dist',
#  '4th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '4th_closest_to_0_dist_x_atomic_mass',
#  '4th_closest_to_0_valence',
#  '4th_closest_to_0_valence_x_cube_inv_dist',
#  '4th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '4th_closest_to_1_dist_x_atomic_mass',
#  '4th_closest_to_1_valence',
#  '4th_closest_to_1_valence_x_cube_inv_dist',
#  '5th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '5th_closest_to_0_dist_x_atomic_mass',
#  '5th_closest_to_0_valence_x_cube_inv_dist',
#  '5th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '5th_closest_to_1_dist_x_atomic_mass',
#  '5th_closest_to_1_valence',
#  '5th_closest_to_1_valence_x_cube_inv_dist',
#  '6th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '6th_closest_to_0_dist_x_atomic_mass',
#  '6th_closest_to_0_valence_x_cube_inv_dist',
#  '6th_closest_to_1_atomic_mass',
#  '6th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '6th_closest_to_1_dist_x_atomic_mass',
#  '6th_closest_to_1_valence',
#  '6th_closest_to_1_valence_x_cube_inv_dist',
#  '7th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '7th_closest_to_0_dist_x_atomic_mass',
#  '7th_closest_to_0_valence_x_cube_inv_dist',
#  '7th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '7th_closest_to_1_dist_x_atomic_mass',
#  '7th_closest_to_1_valence_x_cube_inv_dist',
#  '8th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '8th_closest_to_0_dist_x_atomic_mass',
#  '8th_closest_to_0_valence_x_cube_inv_dist',
#  '8th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '8th_closest_to_1_dist_x_atomic_mass',
#  '8th_closest_to_1_valence_x_cube_inv_dist',
#  '9th_closest_to_0_atomic_mass_x_cube_inv_dist',
#  '9th_closest_to_0_dist_x_atomic_mass',
#  '9th_closest_to_0_valence_x_cube_inv_dist',
#  '9th_closest_to_1_atomic_mass_x_cube_inv_dist',
#  '9th_closest_to_1_dist_x_atomic_mass',
#  '9th_closest_to_1_valence_x_cube_inv_dist',
#  'N1',
#  'N2',
#  'adC1',
#  'adC2',
#  'adC3',
#  'adC4',
#  'adH1',
#  'adH2',
#  'adN1',
#  'adN2',
#  'angle_0_10th0_1',
#  'angle_0_11th0_1',
#  'angle_0_1_2nd1',
#  'angle_0_1_3rd1',
#  'angle_0_1_4th1',
#  'angle_0_1_5th1',
#  'angle_0_1_closest1',
#  'angle_0_2nd0_1',
#  'angle_0_2nd1_1',
#  'angle_0_3rd0_1',
#  'angle_0_3rd1_1',
#  'angle_0_4th0_1',
#  'angle_0_4th1_1',
#  'angle_0_5th0_1',
#  'angle_0_5th1_1',
#  'angle_0_6th0_1',
#  'angle_0_6th1_1',
#  'angle_0_7th0_1',
#  'angle_0_7th1_1',
#  'angle_0_8th0_1',
#  'angle_0_9th0_1',
#  'angle_0_closest0_1',
#  'angle_0_closest1_1',
#  'angle_1_0_10th0',
#  'angle_1_0_10th1',
#  'angle_1_0_11th0',
#  'angle_1_0_11th1',
#  'angle_1_0_2nd0',
#  'angle_1_0_3rd0',
#  'angle_1_0_4th0',
#  'angle_1_0_5th0',
#  'angle_1_0_6th0',
#  'angle_1_0_6th1',
#  'angle_1_0_7th0',
#  'angle_1_0_7th1',
#  'angle_1_0_8th0',
#  'angle_1_0_8th1',
#  'angle_1_0_9th0',
#  'angle_1_0_9th1',
#  'angle_1_0_closest0',
#  'angle_clos_0_2nd',
#  'angle_clos_1_2nd',
#  'atom1_valence',
#  'atomic_mass_not_0_max',
#  'atomic_mass_not_1_max',
#  'atomic_mass_not_1_std',
#  'closest_to_0_atomic_mass_x_cube_inv_dist',
#  'closest_to_0_dist_x_atomic_mass',
#  'closest_to_0_spin_multiplicity',
#  'closest_to_0_spin_multiplicity_x_cube_inv_dist',
#  'closest_to_0_valence_x_cube_inv_dist',
#  'closest_to_1_atomic_mass_x_cube_inv_dist',
#  'closest_to_1_atomic_number',
#  'closest_to_1_dist_x_atomic_mass',
#  'closest_to_1_spin_multiplicity',
#  'closest_to_1_spin_multiplicity_x_cube_inv_dist',
#  'closest_to_1_valence_x_cube_inv_dist',
#  'distC0',
#  'distC1',
#  'dist_to_0_max',
#  'dist_to_0_mean',
#  'dist_to_0_min',
#  'dist_to_0_std',
#  'dist_to_1_max',
#  'dist_to_1_mean',
#  'dist_to_1_std',
#  'distance',
#  'distance_10th_closest_to_0',
#  'distance_10th_closest_to_0_cube_inverse',
#  'distance_10th_closest_to_1',
#  'distance_10th_closest_to_1_cube_inverse',
#  'distance_2nd_closest_to_0',
#  'distance_2nd_closest_to_0_cube_inverse',
#  'distance_2nd_closest_to_1',
#  'distance_2nd_closest_to_1_cube_inverse',
#  'distance_3rd_closest_to_0',
#  'distance_3rd_closest_to_0_cube_inverse',
#  'distance_3rd_closest_to_1',
#  'distance_3rd_closest_to_1_cube_inverse',
#  'distance_4th_closest_to_0',
#  'distance_4th_closest_to_0_cube_inverse',
#  'distance_4th_closest_to_1',
#  'distance_4th_closest_to_1_cube_inverse',
#  'distance_5th_closest_to_0',
#  'distance_5th_closest_to_0_cube_inverse',
#  'distance_5th_closest_to_1',
#  'distance_5th_closest_to_1_cube_inverse',
#  'distance_6th_closest_to_0',
#  'distance_6th_closest_to_0_cube_inverse',
#  'distance_6th_closest_to_1',
#  'distance_6th_closest_to_1_cube_inverse',
#  'distance_7th_closest_to_0',
#  'distance_7th_closest_to_0_cube_inverse',
#  'distance_7th_closest_to_1',
#  'distance_7th_closest_to_1_cube_inverse',
#  'distance_8th_closest_to_0',
#  'distance_8th_closest_to_0_cube_inverse',
#  'distance_8th_closest_to_1',
#  'distance_8th_closest_to_1_cube_inverse',
#  'distance_9th_closest_to_0',
#  'distance_9th_closest_to_0_cube_inverse',
#  'distance_9th_closest_to_1',
#  'distance_9th_closest_to_1_cube_inverse',
#  'distance_closest_to_0',
#  'distance_closest_to_0_cube_inverse',
#  'distance_closest_to_1',
#  'distance_closest_to_1_cube_inverse',
#  'feat_acsf_g2_C_[1, 2]_atom0',
#  'feat_acsf_g2_C_[1, 2]_atom1',
#  'feat_acsf_g2_C_[1, 6]_atom0',
#  'feat_acsf_g2_C_[1, 6]_atom1',
#  'feat_acsf_g2_H_[1, 2]_atom0',
#  'feat_acsf_g2_H_[1, 2]_atom1',
#  'feat_acsf_g2_H_[1, 6]_atom0',
#  'feat_acsf_g2_H_[1, 6]_atom1',
#  'feat_acsf_g2_N_[0.1, 6]_atom1',
#  'feat_acsf_g2_N_[1, 2]_atom0',
#  'feat_acsf_g2_N_[1, 2]_atom1',
#  'feat_acsf_g2_N_[1, 6]_atom0',
#  'feat_acsf_g2_N_[1, 6]_atom1',
#  'feat_acsf_g2_O_[0.1, 6]_atom0',
#  'feat_acsf_g2_O_[0.1, 6]_atom1',
#  'feat_acsf_g2_O_[1, 2]_atom0',
#  'feat_acsf_g2_O_[1, 2]_atom1',
#  'feat_acsf_g2_O_[1, 6]_atom0',
#  'feat_acsf_g2_O_[1, 6]_atom1',
#  'feat_acsf_g4_C_C_[0.01, 4, -1]_atom0',
#  'feat_acsf_g4_C_C_[0.01, 4, -1]_atom1',
#  'feat_acsf_g4_C_C_[0.01, 4, 1]_atom0',
#  'feat_acsf_g4_C_C_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_C_C_[0.1, 4, -1]_atom0',
#  'feat_acsf_g4_C_C_[0.1, 4, -1]_atom1',
#  'feat_acsf_g4_C_C_[0.1, 4, 1]_atom0',
#  'feat_acsf_g4_C_C_[0.1, 4, 1]_atom1',
#  'feat_acsf_g4_C_C_[1, 4, -1]_atom0',
#  'feat_acsf_g4_C_C_[1, 4, -1]_atom1',
#  'feat_acsf_g4_C_C_[1, 4, 1]_atom0',
#  'feat_acsf_g4_C_C_[1, 4, 1]_atom1',
#  'feat_acsf_g4_C_H_[0.01, 4, -1]_atom0',
#  'feat_acsf_g4_C_H_[0.01, 4, -1]_atom1',
#  'feat_acsf_g4_C_H_[0.1, 4, -1]_atom0',
#  'feat_acsf_g4_C_H_[0.1, 4, -1]_atom1',
#  'feat_acsf_g4_C_H_[0.1, 4, 1]_atom0',
#  'feat_acsf_g4_C_H_[1, 4, -1]_atom0',
#  'feat_acsf_g4_C_H_[1, 4, -1]_atom1',
#  'feat_acsf_g4_C_H_[1, 4, 1]_atom0',
#  'feat_acsf_g4_C_H_[1, 4, 1]_atom1',
#  'feat_acsf_g4_H_H_[0.01, 4, -1]_atom0',
#  'feat_acsf_g4_H_H_[0.1, 4, -1]_atom0',
#  'feat_acsf_g4_H_H_[0.1, 4, -1]_atom1',
#  'feat_acsf_g4_H_H_[0.1, 4, 1]_atom0',
#  'feat_acsf_g4_H_H_[1, 4, -1]_atom0',
#  'feat_acsf_g4_H_H_[1, 4, -1]_atom1',
#  'feat_acsf_g4_H_H_[1, 4, 1]_atom0',
#  'feat_acsf_g4_H_H_[1, 4, 1]_atom1',
#  'feat_acsf_g4_N_C_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_N_C_[0.1, 4, -1]_atom0',
#  'feat_acsf_g4_N_C_[0.1, 4, -1]_atom1',
#  'feat_acsf_g4_N_C_[0.1, 4, 1]_atom0',
#  'feat_acsf_g4_N_C_[0.1, 4, 1]_atom1',
#  'feat_acsf_g4_N_C_[1, 4, -1]_atom0',
#  'feat_acsf_g4_N_C_[1, 4, -1]_atom1',
#  'feat_acsf_g4_N_C_[1, 4, 1]_atom0',
#  'feat_acsf_g4_N_C_[1, 4, 1]_atom1',
#  'feat_acsf_g4_N_H_[0.01, 4, 1]_atom0',
#  'feat_acsf_g4_N_H_[0.1, 4, -1]_atom0',
#  'feat_acsf_g4_N_H_[0.1, 4, -1]_atom1',
#  'feat_acsf_g4_N_H_[0.1, 4, 1]_atom0',
#  'feat_acsf_g4_N_H_[0.1, 4, 1]_atom1',
#  'feat_acsf_g4_N_H_[1, 4, -1]_atom0',
#  'feat_acsf_g4_N_H_[1, 4, -1]_atom1',
#  'feat_acsf_g4_N_H_[1, 4, 1]_atom0',
#  'feat_acsf_g4_N_H_[1, 4, 1]_atom1',
#  'feat_acsf_g4_N_N_[0.1, 4, -1]_atom1',
#  'feat_acsf_g4_N_N_[0.1, 4, 1]_atom0',
#  'feat_acsf_g4_N_N_[0.1, 4, 1]_atom1',
#  'feat_acsf_g4_N_N_[1, 4, -1]_atom1',
#  'feat_acsf_g4_N_N_[1, 4, 1]_atom0',
#  'feat_acsf_g4_N_N_[1, 4, 1]_atom1',
#  'feat_acsf_g4_O_C_[0.01, 4, -1]_atom0',
#  'feat_acsf_g4_O_C_[0.01, 4, -1]_atom1',
#  'feat_acsf_g4_O_C_[0.01, 4, 1]_atom0',
#  'feat_acsf_g4_O_C_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_O_C_[0.1, 4, -1]_atom0',
#  'feat_acsf_g4_O_C_[0.1, 4, -1]_atom1',
#  'feat_acsf_g4_O_C_[0.1, 4, 1]_atom0',
#  'feat_acsf_g4_O_C_[0.1, 4, 1]_atom1',
#  'feat_acsf_g4_O_C_[1, 4, -1]_atom0',
#  'feat_acsf_g4_O_C_[1, 4, -1]_atom1',
#  'feat_acsf_g4_O_C_[1, 4, 1]_atom0',
#  'feat_acsf_g4_O_C_[1, 4, 1]_atom1',
#  'feat_acsf_g4_O_H_[0.01, 4, -1]_atom0',
#  'feat_acsf_g4_O_H_[0.01, 4, 1]_atom1',
#  'feat_acsf_g4_O_H_[0.1, 4, -1]_atom0',
#  'feat_acsf_g4_O_H_[0.1, 4, -1]_atom1',
#  'feat_acsf_g4_O_H_[0.1, 4, 1]_atom0',
#  'feat_acsf_g4_O_H_[0.1, 4, 1]_atom1',
#  'feat_acsf_g4_O_H_[1, 4, -1]_atom0',
#  'feat_acsf_g4_O_H_[1, 4, -1]_atom1',
#  'feat_acsf_g4_O_H_[1, 4, 1]_atom0',
#  'feat_acsf_g4_O_H_[1, 4, 1]_atom1',
#  'feat_acsf_g4_O_N_[0.1, 4, -1]_atom0',
#  'feat_acsf_g4_O_N_[0.1, 4, 1]_atom0',
#  'feat_acsf_g4_O_N_[0.1, 4, 1]_atom1',
#  'feat_acsf_g4_O_N_[1, 4, -1]_atom0',
#  'feat_acsf_g4_O_N_[1, 4, -1]_atom1',
#  'feat_acsf_g4_O_N_[1, 4, 1]_atom0',
#  'feat_acsf_g4_O_N_[1, 4, 1]_atom1',
#  'feat_acsf_g4_O_O_[0.01, 4, -1]_atom0',
#  'feat_acsf_g4_O_O_[0.01, 4, -1]_atom1',
#  'feat_acsf_g4_O_O_[0.1, 4, -1]_atom0',
#  'feat_acsf_g4_O_O_[0.1, 4, -1]_atom1',
#  'feat_acsf_g4_O_O_[0.1, 4, 1]_atom0',
#  'feat_acsf_g4_O_O_[0.1, 4, 1]_atom1',
#  'feat_acsf_g4_O_O_[1, 4, -1]_atom0',
#  'feat_acsf_g4_O_O_[1, 4, -1]_atom1',
#  'feat_acsf_g4_O_O_[1, 4, 1]_atom0',
#  'feat_acsf_g4_O_O_[1, 4, 1]_atom1',
#  'inv_dist0',
#  'inv_dist0E',
#  'inv_dist0R',
#  'inv_dist1E',
#  'inv_dist1R',
#  'inv_distPE',
#  'inv_distPR',
#  'link0',
#  'link1',
#  'linkM0',
#  'linkN',
#  'max_molecule_atom_0_dist_xyz',
#  'max_molecule_atom_1_dist_xyz',
#  'mean_molecule_atom_0_dist_xyz',
#  'mean_molecule_atom_1_dist_xyz',
#  'min_molecule_atom_0_dist_xyz',
#  'min_molecule_atom_1_dist_xyz',
#  'sd_molecule_atom_0_dist_xyz',
#  'sd_molecule_atom_1_dist_xyz',
#  'val_not_0_mean',
#  'val_not_0_std',
#  'val_not_1_mean',
#  'val_not_1_std',
#  'yukawa_C.x',
#  'yukawa_N.y',
#  'yukawa_O.x',
#  'yukawa_O.y']

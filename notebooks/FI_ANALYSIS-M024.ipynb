# %% [markdown]
# # Evaluation of Model Results
# ## Model M022

# %%
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
import os
import pprint
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

test = pd.read_csv('../input/test.csv')

# %%
tracking = pd.read_csv('../tracking/tracking.csv')
BEST_PUBLIC_RUN_ID = tracking.loc[tracking['lb_score'] == tracking['lb_score'].min()]['run_id'].values[0]
BEST_PUBLIC_SCORE = tracking.loc[tracking['lb_score'] == tracking['lb_score'].min()]['lb_score'].values[0]
print('------------------------------------------------------')
print('Currently the best public LB score is model {} with a score of {:.4f}'.format(BEST_PUBLIC_RUN_ID,
                                                                                     BEST_PUBLIC_SCORE))
print('------------------------------------------------------')
tracking
# Out:
# ------------------------------------------------------
# Currently the best public LB score is model 0627_0017 with a score of -1.2640
# ------------------------------------------------------
#        run_id model_number eval_metric  n_estimators  early_stopping_rounds  ...  1JHN_csv_save_sec  2JHN_csv_save_sec  2JHC_csv_save_sec  3JHH_csv_save_sec  3JHC_csv_save_sec
# 0   0610_1341         M010         mae      500000.0                  500.0  ...                NaN                NaN                NaN                NaN                NaN
# 1   0611_0308         M012         mae      500000.0                  500.0  ...                NaN                NaN                NaN                NaN                NaN
# 2   0611_1250         M013         mae       50000.0                  500.0  ...                NaN                NaN                NaN                NaN                NaN
# 3   0611_1249         M014         mae      500000.0                  500.0  ...                NaN                NaN                NaN                NaN                NaN
# 4   0613_0402         M015         mae      500000.0                  500.0  ...                NaN                NaN                NaN                NaN                NaN
# 5   0618_0349         M016   group_mae      500000.0                  500.0  ...                NaN                NaN                NaN                NaN                NaN
# 6   0621_0331         M017   group_mae      500000.0                  500.0  ...           30540.03           31977.75                NaN                NaN                NaN
# 7   0623_1352         M018   group_mae        5000.0                  500.0  ...              24.83              24.83              25.61              26.03              27.06
# 8   0623_1435         M019   group_mae       50000.0                  500.0  ...              24.55              24.57              25.37              25.68              26.69
# 9   0624_0121         M020   group_mae      500000.0                  500.0  ...              23.98              24.05              25.12              25.29              26.24
# 10  0626_0129         M021   group_mae      500000.0                  500.0  ...              25.63              25.41              25.80              26.56              27.70
# 11  0626_2145         M022   group_mae      500000.0                  500.0  ...              26.00              26.00              28.00              29.00              30.00
# 12  0627_0017         M023   group_mae      500000.0                  500.0  ...              26.00              26.00              27.00              28.00              30.00
# 13  0627_1434         M024   group_mae      500000.0                  500.0  ...              26.00              26.00              28.00              29.00              30.00
#
# [14 rows x 70 columns]

# %%
RUN_ID = '0627_1434'
MODEL_NO = 'M024'
sub_file = [x for x in os.listdir('../submissions/') if RUN_ID in x][0]
fi_file = [x for x in os.listdir('../fi/') if RUN_ID in x][0]
oof_file = [x for x in os.listdir('../oof') if RUN_ID in x][0]
# Read in files for new RUN_ID
sub = pd.read_csv(f'../submissions/{sub_file}')
oof = pd.read_csv(f'../oof/{oof_file}')
fi = pd.read_csv(f'../fi/{fi_file}')
# Read in files for best RUN_ID
bsub_file = [x for x in os.listdir('../submissions/') if BEST_PUBLIC_RUN_ID in x][0]
bfi_file = [x for x in os.listdir('../fi/') if BEST_PUBLIC_RUN_ID in x][0]
boof_file = [x for x in os.listdir('../oof') if BEST_PUBLIC_RUN_ID in x][0]
bsub = pd.read_csv(f'../submissions/{bsub_file}')
boof = pd.read_csv(f'../oof/{boof_file}')
bfi = pd.read_csv(f'../fi/{bfi_file}')

# %% [markdown]
# ## Features with no importance

# %%
fi_mean = fi.groupby('feature').mean()
no_importance_features = fi_mean.loc[fi_mean['importance'] == 0].index.tolist()
print('Features with no importance at all')
pprint.pprint(no_importance_features)
# Out:
# Features with no importance at all
# ['is_bond']

# %% [markdown]
# ## Feature with no importance by type

# %%
fi_minus_non_imp = fi.loc[~fi['feature'].isin(no_importance_features)]
for i, d in fi_minus_non_imp.groupby('type'):
    d_mean = d.groupby('feature').mean()
    d_mean.loc[d_mean['importance'] == 0]
    print(d_mean.loc[d_mean['importance'] == 0].index)
# Out:
# Index(['closest_to_0_atomic_mass', 'closest_to_0_spin_multiplicity',
#        'closest_to_0_valence', 'closest_to_1_atomic_mass',
#        'closest_to_1_spin_multiplicity', 'closest_to_1_valence',
#        'distance_closest_to_0', 'left_middle_average_angle',
#        'right_middle_average_angle', 'tor_ang_2leftright_count',
#        'tor_ang_2leftright_max', 'tor_ang_2leftright_mean',
#        'tor_ang_2leftright_min'],
#       dtype='object', name='feature')
# Index(['closest_to_0_atomic_mass', 'closest_to_0_spin_multiplicity',
#        'closest_to_0_valence', 'closest_to_1_atomic_mass',
#        'closest_to_1_spin_multiplicity', 'closest_to_1_valence',
#        'distance_closest_to_0', 'is_bond_3rd_closest_to_1',
#        'left_middle_average_angle', 'right_middle_average_angle',
#        'tor_ang_2leftright_count', 'tor_ang_2leftright_max',
#        'tor_ang_2leftright_mean', 'tor_ang_2leftright_min'],
#       dtype='object', name='feature')
# Index(['tor_ang_2leftleft_count', 'tor_ang_2leftleft_max',
#        'tor_ang_2leftleft_mean', 'tor_ang_2leftleft_min',
#        'tor_ang_2leftright_count'],
#       dtype='object', name='feature')
# Index(['2nd_closest_to_0_atomic_mass', '2nd_closest_to_0_spin_multiplicity',
#        '2nd_closest_to_0_valence', '2nd_closest_to_1_atomic_mass',
#        '2nd_closest_to_1_spin_multiplicity', '2nd_closest_to_1_valence',
#        'atom1_spin_multiplicity', 'atom1_valence',
#        'closest_to_0_spin_multiplicity', 'closest_to_1_atomic_mass',
#        'closest_to_1_spin_multiplicity', 'closest_to_1_valence',
#        'is_bond_3rd_closest_to_1', 'left_middle_average_angle',
#        'right_middle_average_angle', 'tor_ang_2leftleft_count',
#        'tor_ang_2leftleft_max', 'tor_ang_2leftleft_mean',
#        'tor_ang_2leftleft_min', 'tor_ang_2leftright_count',
#        'tor_ang_2leftright_max', 'tor_ang_2leftright_mean',
#        'tor_ang_2leftright_min'],
#       dtype='object', name='feature')
# Index(['is_bond_3rd_closest_to_1', 'tor_ang_2leftleft_count',
#        'tor_ang_2leftleft_max', 'tor_ang_2leftleft_mean',
#        'tor_ang_2leftleft_min'],
#       dtype='object', name='feature')
# Index(['left_middle_average_angle', 'right_middle_average_angle',
#        'tor_ang_2leftleft_count', 'tor_ang_2leftleft_max',
#        'tor_ang_2leftleft_mean', 'tor_ang_2leftleft_min',
#        'tor_ang_2leftright_count', 'tor_ang_2leftright_max',
#        'tor_ang_2leftright_mean', 'tor_ang_2leftright_min'],
#       dtype='object', name='feature')
# Index(['atom1_spin_multiplicity', 'atom1_valence', 'is_bond_3rd_closest_to_1',
#        'left_middle_average_angle', 'right_middle_average_angle',
#        'tor_ang_2leftleft_count', 'tor_ang_2leftleft_max',
#        'tor_ang_2leftleft_mean', 'tor_ang_2leftleft_min',
#        'tor_ang_2leftright_count', 'tor_ang_2leftright_max',
#        'tor_ang_2leftright_mean', 'tor_ang_2leftright_min'],
#       dtype='object', name='feature')
# Index(['is_bond_3rd_closest_to_1', 'left_middle_average_angle',
#        'right_middle_average_angle', 'tor_ang_2leftleft_count',
#        'tor_ang_2leftleft_max', 'tor_ang_2leftleft_mean',
#        'tor_ang_2leftleft_min', 'tor_ang_2leftright_count',
#        'tor_ang_2leftright_max', 'tor_ang_2leftright_mean',
#        'tor_ang_2leftright_min'],
#       dtype='object', name='feature')

# %%
for i, d in fi_minus_non_imp.groupby('type'):
    plt.figure(figsize=(16, 30));
    sns.barplot(x="importance", y="feature", data=d.sort_values(by="importance", ascending=False));
    plt.title('{} - LGB Features (avg over folds)'.format(i))
    plt.show()

# %% [markdown]
# # Compare Submission Files

# %%
sub['type'] = test['type']
bsub['type'] = test['type']

# %%
for i, d in sub.groupby('type'):
    d['scalar_coupling_constant'].plot(kind='hist', figsize=(15, 3), title=i, bins=1000)
    # also plot best sub
    d_bsub = bsub.loc[bsub['type'] == i]
    d_bsub['scalar_coupling_constant'].plot(kind='hist', figsize=(15, 3), title=i, bins=1000, alpha=0.3)
    plt.show()

# %%
sub['bscalar_coupling_constant'] = bsub['scalar_coupling_constant']
# Scatter plot of submission
for i, d in sub.groupby('type'):
    d.plot(x='bscalar_coupling_constant', y='scalar_coupling_constant', kind='scatter', figsize=(5, 5), title=i)

# %% [markdown]
# # Compare OOF

# %%
for i, d in oof.groupby('type'):
    d['scalar_coupling_constant'].plot(kind='hist', figsize=(15, 3), title=i, bins=1000)
    # also plot best sub
    d_boof = boof.loc[boof['type'] == i]
    d_boof['scalar_coupling_constant'].plot(kind='hist', figsize=(15, 3), title=i, bins=1000, alpha=0.3)
    plt.show()

# %% [markdown]
# # Update Leaderboard score

# %%
LB_SCORE = -1.382
tracking = pd.read_csv('../tracking/tracking.csv')
tracking.loc[tracking['run_id'] == RUN_ID, 'lb_score'] = LB_SCORE
tracking.to_csv('../tracking/tracking.csv', index=False)

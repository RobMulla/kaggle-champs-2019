# %%
import pandas as pd

# %%
fi = pd.read_csv('../fi/M018_0623_1352_fi_lgb_2folds_1.6174CV_5000iter_0.1lr.csv')

# %%
fi
# Out:
#                                   feature  importance  fold
# 0                     bond_lengths_mean_y       21297     1
# 1          molecule_atom_index_0_dist_max        6742     1
# 2                     bond_lengths_mean_x        6740     1
# 3         molecule_atom_index_0_dist_mean        5386     1
# 4          molecule_atom_index_0_dist_std        5235     1
# 5                        molecule_couples        5385     1
# 6           molecule_atom_index_0_y_1_std        6264     1
# 7                      molecule_dist_mean        5963     1
# 8                       molecule_dist_max        6123     1
# 9                                  dist_y        5480     1
# 10          molecule_atom_index_0_z_1_std        6043     1
# 11         molecule_atom_index_1_dist_max        5550     1
# 12         molecule_atom_index_1_dist_min        4190     1
# 13          molecule_atom_index_0_x_1_std        5666     1
# 14         molecule_atom_index_1_dist_std        4462     1
# ...

# %%
fi.groupby('feature').mean()['importance'].sort_values().plot(kind='barh', figsize=(15, 15))

# %%
fi[:49].set_index('feature')['importance'].sort_values().plot(kind='barh', figsize=(15, 15))

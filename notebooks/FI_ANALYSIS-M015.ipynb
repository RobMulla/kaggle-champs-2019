# %%
import pandas as pd

# %%
fi = pd.read_csv('../fi/M015_0613_0402_fi_lgb_5folds_0.7914CV_500000iter_0.3lr.csv')

# %%
fi.groupby('feature').mean()['importance'].sort_values().plot(kind='barh', figsize=(15, 15))

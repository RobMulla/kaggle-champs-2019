# %%
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
tr = pd.read_parquet('../data/FE008_train.parquet')

# %%
tracking = pd.read_csv('../tracking/tracking.csv')
N_FEATURES = int(tracking.loc[tracking['run_id'] == '0626_0129']['n_features'].values[0]) - 1
N_FOLDS = int(tracking.loc[tracking['run_id'] == '0626_0129']['n_fold'].values[0])
fi = pd.read_csv('../fi/M021_0626_0129_fi_lgb_2folds_1.5972CV_500000iter_0.3lr.csv')
fi["importance"] /= N_FOLDS

# %%
fi2 = fi.loc[(N_FEATURES*2) * 0:((N_FEATURES*2) * 1)-1]
cols = fi2[["feature", "importance"]].groupby("feature").mean().sort_values(
    by="importance", ascending=False)[:50].index

# best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

plt.figure(figsize=(16, 12));
sns.barplot(x="importance", y="feature", data=fi2.sort_values(by="importance", ascending=False));
plt.title('1JHC - LGB Features (avg over folds)');

# %%
fi2 = fi.loc[(N_FEATURES*2) * 1:((N_FEATURES*2) * 2)-1]
cols = fi2[["feature", "importance"]].groupby("feature").mean().sort_values(
    by="importance", ascending=False)[:50].index

# best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

plt.figure(figsize=(16, 12));
sns.barplot(x="importance", y="feature", data=fi2.sort_values(by="importance", ascending=False));
plt.title('2JHH - LGB Features (avg over folds)');

# %%
fi2 = fi.loc[(N_FEATURES*2) * 2:((N_FEATURES*2) * 3)-1]
cols = fi2[["feature", "importance"]].groupby("feature").mean().sort_values(
    by="importance", ascending=False)[:50].index

# best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

plt.figure(figsize=(16, 12));
sns.barplot(x="importance", y="feature", data=fi2.sort_values(by="importance", ascending=False));
plt.title('1JHN - LGB Features (avg over folds)');

# %%
fi2 = fi.loc[(N_FEATURES*2) * 3:((N_FEATURES*2) * 4)-1]
cols = fi2[["feature", "importance"]].groupby("feature").mean().sort_values(
    by="importance", ascending=False)[:50].index

# best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

plt.figure(figsize=(16, 12));
sns.barplot(x="importance", y="feature", data=fi2.sort_values(by="importance", ascending=False));
plt.title('2JHN - LGB Features (avg over folds)');

# %%
fi2 = fi.loc[(N_FEATURES*2) * 4:((N_FEATURES*2) * 5)-1]
cols = fi2[["feature", "importance"]].groupby("feature").mean().sort_values(
    by="importance", ascending=False)[:50].index

# best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

plt.figure(figsize=(16, 12));
sns.barplot(x="importance", y="feature", data=fi2.sort_values(by="importance", ascending=False));
plt.title('2JHC - LGB Features (avg over folds)');

# %%
fi2 = fi.loc[(N_FEATURES*2) * 5:((N_FEATURES*2) * 6)-1]
cols = fi2[["feature", "importance"]].groupby("feature").mean().sort_values(
    by="importance", ascending=False)[:50].index

# best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

plt.figure(figsize=(16, 12));
sns.barplot(x="importance", y="feature", data=fi2.sort_values(by="importance", ascending=False));
plt.title('3JHH - LGB Features (avg over folds)');

# %%
fi2 = fi.loc[(N_FEATURES*2) * 6:((N_FEATURES*2) * 7)-1]
cols = fi2[["feature", "importance"]].groupby("feature").mean().sort_values(
    by="importance", ascending=False)[:50].index

# best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

plt.figure(figsize=(16, 12));
sns.barplot(x="importance", y="feature", data=fi2.sort_values(by="importance", ascending=False));
plt.title('3JHC - LGB Features (avg over folds)');

# %%
fi2 = fi.loc[(N_FEATURES*2) * 7:((N_FEATURES*2) * 8)-1]
cols = fi2[["feature", "importance"]].groupby("feature").mean().sort_values(
    by="importance", ascending=False)[:50].index

# best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

plt.figure(figsize=(16, 12));
sns.barplot(x="importance", y="feature", data=fi2.sort_values(by="importance", ascending=False));
plt.title('3JHN - LGB Features (avg over folds)');
